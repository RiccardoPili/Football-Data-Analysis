# %% [markdown]
# # Importing Data & Libraries

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

games_df = pd.read_csv("/Users/pato/Desktop/FootballData/games.csv")

# %% [markdown]
# # Data Preparation

# %%
games_df.shape
# Out:
# (65216, 23)

# %%
games_df.head(10)
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 1  2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2  2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 3  2222664            RU1    2012   8. Matchday  2012-09-15           932
# 4  2222683            RU1    2012  12. Matchday  2012-10-22          2696
# 5  2222685            RU1    2012  19. Matchday  2012-12-10          2698
# 6  2222734            RU1    2012  19. Matchday  2012-12-07          1083
# 7  2222735            RU1    2012  18. Matchday  2012-12-02          2700
# 8  2222739            RU1    2012  22. Matchday  2013-03-31         16704
# 9  2222775            RU1    2012  28. Matchday  2013-05-12          3725
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0           232                2                1                 2.0  ...
# ...

# %%
games_df = games_df.set_index('game_id')
games_df.head(10)
# Out:
#         competition_id  season         round        date  home_club_id  \
# game_id
# 2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 2222664            RU1    2012   8. Matchday  2012-09-15           932
# 2222683            RU1    2012  12. Matchday  2012-10-22          2696
# 2222685            RU1    2012  19. Matchday  2012-12-10          2698
# 2222734            RU1    2012  19. Matchday  2012-12-07          1083
# 2222735            RU1    2012  18. Matchday  2012-12-02          2700
# 2222739            RU1    2012  22. Matchday  2013-03-31         16704
# 2222775            RU1    2012  28. Matchday  2013-05-12          3725
#
#          away_club_id  home_club_goals  away_club_goals  home_club_position  \
# game_id
# 2222597           232                2                1                 2.0
# ...

# %%
games_df.columns
# Out:
# Index(['competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
# handling NA values
games_df.isna().sum()
# Out:
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  0
# away_club_id                  0
# home_club_goals               0
# away_club_goals               0
# home_club_position        19454
# away_club_position        19454
# home_club_manager_name      742
# away_club_manager_name      742
# stadium                     211
# attendance                 9512
# referee                     594
# url                           0
# home_club_formation       62347
# away_club_formation       62328
# home_club_name            11252
# away_club_name            10049
# aggregate                     0
# competition_type              0
# dtype: int64

# %%
# removing NA rows for home_club_position
games_df = games_df.loc[~games_df['home_club_position'].isna()]

# removing NA rows for away_club_position
games_df = games_df.loc[~games_df['away_club_position'].isna()]

# removing NA rows for home_club_manager_name
games_df = games_df.loc[~games_df['home_club_manager_name'].isna()]

# removing NA rows for away_club_manager_name
games_df = games_df.loc[~games_df['away_club_manager_name'].isna()]

# removing NA rows for stadium
games_df = games_df.loc[~games_df['stadium'].isna()]

# removing NA rows for attendance
games_df = games_df.loc[~games_df['attendance'].isna()]

# removing NA rows for referee
games_df = games_df.loc[~games_df['referee'].isna()]

# removing NA rows for home_club_formation
games_df = games_df.loc[~games_df['home_club_formation'].isna()]

# removing NA rows for away_club_formation
games_df = games_df.loc[~games_df['away_club_formation'].isna()]

# removing NA rows for home_club_name
games_df = games_df.loc[~games_df['home_club_name'].isna()]

games_df.isna().sum()
# Out:
# competition_id            0
# season                    0
# round                     0
# date                      0
# home_club_id              0
# away_club_id              0
# home_club_goals           0
# away_club_goals           0
# home_club_position        0
# away_club_position        0
# home_club_manager_name    0
# away_club_manager_name    0
# stadium                   0
# attendance                0
# referee                   0
# url                       0
# home_club_formation       0
# away_club_formation       0
# home_club_name            0
# away_club_name            0
# aggregate                 0
# competition_type          0
# dtype: int64

# %%
games_df.loc[games_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [competition_id, season, round, date, home_club_id, away_club_id, home_club_goals, away_club_goals, home_club_position, away_club_position, home_club_manager_name, away_club_manager_name, stadium, attendance, referee, url, home_club_formation, away_club_formation, home_club_name, away_club_name, aggregate, competition_type]
# Index: []
#
# [0 rows x 22 columns]

# %%
games_df.dtypes
# Out:
# competition_id             object
# season                      int64
# round                      object
# date                       object
# home_club_id                int64
# away_club_id                int64
# home_club_goals             int64
# away_club_goals             int64
# home_club_position        float64
# away_club_position        float64
# home_club_manager_name     object
# away_club_manager_name     object
# stadium                    object
# attendance                float64
# referee                    object
# url                        object
# home_club_formation        object
# away_club_formation        object
# home_club_name             object
# away_club_name             object
# aggregate                  object
# competition_type           object
# dtype: object

# %% [markdown]
# # Data Analysis & Visualization

# %%
#making a dataframe subset and reordering columns
games_df = games_df [
    ['competition_id', 
     'season', 
     'round', 
     'date', 
     'home_club_id',
     'home_club_name',
     'home_club_goals',
     'home_club_position', 
     'home_club_manager_name',
     'home_club_formation', 
     'away_club_id',  
     'away_club_name',
     'away_club_goals',
     'away_club_position', 
     'away_club_manager_name', 
     'away_club_formation', 
     'stadium', 
     'attendance', 
     'referee', 
     #'url',
     'aggregate', 
     'competition_type']
]

games_df.sort_values("home_club_name", ascending = True)
# Out:
#         competition_id  season         round        date  home_club_id  \
# game_id
# 4095969             L1    2023   1. Matchday  2023-08-20            89
# 4096067             L1    2023  12. Matchday  2023-11-25            89
# 4095986             L1    2023   3. Matchday  2023-09-03            89
# 4096005             L1    2023   5. Matchday  2023-09-23            89
# 4096049             L1    2023  10. Matchday  2023-11-04            89
# ...                ...     ...           ...         ...           ...
# 4167381            RU1    2023   7. Matchday  2023-09-03           932
# 4092052            RU1    2023   1. Matchday  2023-07-22           932
# 4174441            RU1    2023  10. Matchday  2023-09-30           932
# 4198828            RU1    2023  12. Matchday  2023-10-21           932
# 4092077            RU1    2023   4. Matchday  2023-08-12           932
#
#                              home_club_name  home_club_goals  \
# game_id
# ...

# %%
games_df = games_df.rename(columns={'aggregate':'score'})

# %%
games_df
# Out:
#         competition_id  season        round        date  home_club_id  \
# game_id
# 4087929            GB1    2023  1. Matchday  2023-08-12           350
# 4087952            GB1    2023  3. Matchday  2023-08-27           762
# 4087962            GB1    2023  4. Matchday  2023-09-02           281
# 4087965            GB1    2023  5. Matchday  2023-09-16           405
# 4089283            DK1    2023  1. Matchday  2023-07-23           678
# ...                ...     ...          ...         ...           ...
# 4097950            NL1    2023  8. Matchday  2023-10-07           723
# 4113067            ES1    2023  7. Matchday  2023-09-26           368
# 4093112            BE1    2023  1. Matchday  2023-07-30           475
# 4089286            DK1    2023  1. Matchday  2023-07-24          2778
# 4097959            NL1    2023  5. Matchday  2023-09-16           383
#
#                                             home_club_name  home_club_goals  \
# game_id
# ...

# %%
# checking variable home_club_name
games_df['home_club_name'].describe()
# Out:
# count               1425
# unique               222
# top       FC Rubin Kazan
# freq                   9
# Name: home_club_name, dtype: object

# %%
# check for goal outliers
ax = games_df.boxplot(column='home_club_goals')
ax.set_title('Numbers of goals in Home Club')
plt.show()

# %%
# remove games outliers
games_df['home_club_goals'].value_counts().plot(kind='bar', title="Number of Goals in Home Club")
plt.show()

# %%
games_df['away_club_goals'].value_counts().plot(kind='bar', title="Number of goals in Away Club")
plt.show()

# %%
games_df['home_club_position'].plot(kind='hist', title="Home Club Position")
plt.show()

# %%
games_df['away_club_position'].value_counts().plot(kind='hist', title="Away Club Position")
plt.show()

# %%
games_df['score'].value_counts().plot(kind='bar', title="Number of Scores")
plt.show()

# %%
games_df['score'].value_counts()
# Out:
# score
# 1:1    164
# 2:1    129
# 1:0    127
# 2:0    105
# 0:0     94
# 0:1     89
# 2:2     88
# 1:2     86
# 0:2     67
# 3:1     58
# 3:0     55
# 1:3     51
# 0:3     40
# 3:2     39
# 4:0     35
# 2:3     30
# 4:1     21
# 3:3     21
# 1:4     18
# 4:2     14
# 0:4     13
# 5:1     12
# 2:4     11
# 5:0     11
# 4:3      6
# 0:5      5
# 6:1      5
# 5:3      4
# 3:4      4
# 1:5      4
# 6:0      4
# 4:4      3
# 5:2      3
# 2:5      2
# 7:0      2
# 8:0      1
# 0:8      1
# 7:1      1
# 0:7      1
# 0:6      1
# Name: count, dtype: int64

# %%
games_df
# Out:
#         competition_id  season        round        date  home_club_id  \
# game_id
# 4087929            GB1    2023  1. Matchday  2023-08-12           350
# 4087952            GB1    2023  3. Matchday  2023-08-27           762
# 4087962            GB1    2023  4. Matchday  2023-09-02           281
# 4087965            GB1    2023  5. Matchday  2023-09-16           405
# 4089283            DK1    2023  1. Matchday  2023-07-23           678
# ...                ...     ...          ...         ...           ...
# 4097950            NL1    2023  8. Matchday  2023-10-07           723
# 4113067            ES1    2023  7. Matchday  2023-09-26           368
# 4093112            BE1    2023  1. Matchday  2023-07-30           475
# 4089286            DK1    2023  1. Matchday  2023-07-24          2778
# 4097959            NL1    2023  5. Matchday  2023-09-16           383
#
#                                             home_club_name  home_club_goals  \
# game_id
# ...
