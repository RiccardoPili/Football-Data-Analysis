# %% [markdown]
# # Importing Data & Libraries

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

competitions_df = pd.read_csv("/Users/pato/Desktop/FootballData/competitions.csv")

# %% [markdown]
# # Data Preparation

# %%
competitions_df.shape
# Out:
# (43, 10)

# %%
competitions_df.columns
# Out:
# Index(['competition_id', 'competition_code', 'name', 'sub_type', 'type',
#        'country_id', 'country_name', 'domestic_league_code', 'confederation',
#        'url'],
#       dtype='object')

# %%
competitions_df.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# ...

# %%
competitions_df.set_index('competition_id')
# Out:
#                                            competition_code  \
# competition_id
# CIT                                               italy-cup
# NLSC                                   johan-cruijff-schaal
# GRP                                         kypello-elladas
# POSU                          supertaca-candido-de-oliveira
# RUSS                                      russian-super-cup
# SUC                                               supercopa
# USC                                          uefa-super-cup
# DK1                                             superligaen
# EL                                            europa-league
# ES1                                                  laliga
# FR1                                                 ligue-1
# IT1                                                 serie-a
# NL1                                              eredivisie
# RUP                                             russian-cup
# ...

# %%
competitions_df.isna().sum()
# Out:
# competition_id          0
# competition_code        0
# name                    0
# sub_type                0
# type                    0
# country_id              0
# country_name            7
# domestic_league_code    7
# confederation           0
# url                     0
# dtype: int64

# %%
competitions_df.convert_dtypes()
# Out:
#    competition_id                             competition_code  \
# 0             CIT                                    italy-cup
# 1            NLSC                         johan-cruijff-schaal
# 2             GRP                              kypello-elladas
# 3            POSU                supertaca-candido-de-oliveira
# 4            RUSS                            russian-super-cup
# 5             SUC                                    supercopa
# 6             USC                               uefa-super-cup
# 7             DK1                                  superligaen
# 8              EL                                europa-league
# 9             ES1                                       laliga
# 10            FR1                                      ligue-1
# 11            IT1                                      serie-a
# 12            NL1                                   eredivisie
# 13            RUP                                  russian-cup
# ...

# %%
competitions_df['country_name']
# Out:
# 0           Italy
# 1     Netherlands
# 2          Greece
# 3        Portugal
# 4          Russia
# 5           Spain
# 6             NaN
# 7         Denmark
# 8             NaN
# 9           Spain
# 10         France
# 11          Italy
# 12    Netherlands
# 13         Russia
# 14       Portugal
# 15        Belgium
# 16        England
# 17            NaN
# 18        England
# 19        Denmark
# 20            NaN
# 21        England
# 22    Netherlands
# 23        Ukraine
# 24        Ukraine
# 25          Spain
# 26            NaN
# 27         Greece
# 28         Turkey
# 29       Portugal
# 30        England
# 31            NaN
# 32        Germany
# 33         Russia
# 34       Scotland
# 35          Italy
# 36        Belgium
# 37            NaN
# 38        Germany
# 39       Scotland
# 40        Ukraine
# 41        Germany
# 42         France
# Name: country_name, dtype: object

# %%
# Non eliminiamo i valori di "Nan" perché appartengono a competizioni non a campionati italiani
competitions_df.loc[competitions_df['country_name'].isna()]
# Out:
#    competition_id                             competition_code  \
# 6             USC                               uefa-super-cup
# 8              EL                                europa-league
# 17            ELQ                  europa-league-qualifikation
# 20           ECLQ  uefa-europa-conference-league-qualifikation
# 26             CL                        uefa-champions-league
# 31           KLUB                                 fifa-klub-wm
# 37            CLQ          uefa-champions-league-qualifikation
#
#                                            name  \
# 6                                uefa-super-cup
# 8                                 europa-league
# 17                  europa-league-qualifikation
# 20  uefa-europa-conference-league-qualifikation
# 26                        uefa-champions-league
# 31                                 fifa-klub-wm
# 37          uefa-champions-league-qualifikation
#
# ...

# %%
competitions_df.loc[competitions_df['country_name'].isna(), 'country_name'] = 'International'

competitions_df
# Out:
#    competition_id                             competition_code  \
# 0             CIT                                    italy-cup
# 1            NLSC                         johan-cruijff-schaal
# 2             GRP                              kypello-elladas
# 3            POSU                supertaca-candido-de-oliveira
# 4            RUSS                            russian-super-cup
# 5             SUC                                    supercopa
# 6             USC                               uefa-super-cup
# 7             DK1                                  superligaen
# 8              EL                                europa-league
# 9             ES1                                       laliga
# 10            FR1                                      ligue-1
# 11            IT1                                      serie-a
# 12            NL1                                   eredivisie
# 13            RUP                                  russian-cup
# ...

# %%
competitions_df.loc[competitions_df['domestic_league_code'].isna(), 'domestic_league_code'] = 'INT'

competitions_df
# Out:
#    competition_id                             competition_code  \
# 0             CIT                                    italy-cup
# 1            NLSC                         johan-cruijff-schaal
# 2             GRP                              kypello-elladas
# 3            POSU                supertaca-candido-de-oliveira
# 4            RUSS                            russian-super-cup
# 5             SUC                                    supercopa
# 6             USC                               uefa-super-cup
# 7             DK1                                  superligaen
# 8              EL                                europa-league
# 9             ES1                                       laliga
# 10            FR1                                      ligue-1
# 11            IT1                                      serie-a
# 12            NL1                                   eredivisie
# 13            RUP                                  russian-cup
# ...

# %% [markdown]
# # Data Analysis & Visualization
