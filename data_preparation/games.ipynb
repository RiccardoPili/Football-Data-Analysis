# %% [markdown]
# # Importing Data & Libraries

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from folder_path import folder_path

games_df = pd.read_csv(f"{folder_path}/games.csv")
competitions_df = pd.read_csv(f"{folder_path}/competitions.csv")

# %% [markdown]
# # Data Preparation

# %%
games_df.shape
# Out:
# (65216, 23)

# %%
games_df
# Out:
#        game_id competition_id  season                     round        date  \
# 0      2222597            RU1    2012               6. Matchday  2012-08-25
# 1      2222627            RU1    2012               5. Matchday  2012-08-20
# 2      2222658            RU1    2012              10. Matchday  2012-09-30
# 3      2222664            RU1    2012               8. Matchday  2012-09-15
# 4      2222683            RU1    2012              12. Matchday  2012-10-22
# ...        ...            ...     ...                       ...         ...
# 65211  2367292             EL    2013                   Group B  2013-11-07
# 65212  2629035            NLP    2015               Third Round  2015-10-27
# 65213  3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 65214  4164101            CGB    2023              Second Round  2023-08-29
# 65215  4013659            FAC    2022              Fourth Round  2023-01-29
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 0              3725           232                2                1
# 1              2696          4128                0                2
# 2              2410           121                0                2
# 3               932          2698                1                0
# 4              2696         12438                0                1
# ...             ...           ...              ...              ...
# 65211           383           419                2                0
# 65212           383         16866                6                0
# 65213           383           713                3                0
# 65214           512          1194                6                1
# 65215           512          3684                3                1
#
#        home_club_position  ...          stadium attendance  \
# 0                     2.0  ...     Akhmat-Arena    21700.0
# 1                    11.0  ...        Metallurg    11400.0
# 2                     2.0  ...     Arena Khimki    12000.0
# 3                     5.0  ...        RZD Arena    11408.0
# 4                    11.0  ...        Metallurg     7534.0
# ...                   ...  ...              ...        ...
# 65211                 NaN  ...  Philips Stadion    10000.0
# 65212                 NaN  ...  Philips Stadion    31000.0
# 65213                 NaN  ...  Philips Stadion    34200.0
# 65214                 NaN  ...   bet365 Stadium     9410.0
# 65215                 NaN  ...   bet365 Stadium    14392.0
#
#                     referee  \
# 0      Vladislav Bezborodov
# 1             Sergey Ivanov
# 2            Sergey Karasev
# 3            Sergey Karasev
# 4         Timur Arslanbekov
# ...                     ...
# 65211        Cristian Balaj
# 65212       Allard Lindhout
# 65213        Anthony Taylor
# 65214     Michael Salisbury
# 65215            David Webb
#
#                                                      url  home_club_formation  \
# 0      https://www.transfermarkt.co.uk/terek-grozny_s...                  NaN
# 1      https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# 2      https://www.transfermarkt.co.uk/cska-moscow_di...                  NaN
# 3      https://www.transfermarkt.co.uk/lokomotiv-mosc...                  NaN
# 4      https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# ...                                                  ...                  ...
# 65211  https://www.transfermarkt.co.uk/spielbericht/i...                  NaN
# 65212  https://www.transfermarkt.co.uk/spielbericht/i...                  NaN
# 65213  https://www.transfermarkt.co.uk/spielbericht/i...                  NaN
# 65214  https://www.transfermarkt.co.uk/spielbericht/i...              4-2-3-1
# 65215  https://www.transfermarkt.co.uk/spielbericht/i...                  NaN
#
#       away_club_formation                                     home_club_name  \
# 0                     NaN                                  RFK Akhmat Grozny
# 1                     NaN                          PFK Krylya Sovetov Samara
# 2                     NaN                                    PFK CSKA Moskva
# 3                     NaN                 Футбольный клуб "Локомотив" Москва
# 4                     NaN                          PFK Krylya Sovetov Samara
# ...                   ...                                                ...
# 65211                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65212                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65213                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65214             4-2-3-1                                         Stoke City
# 65215                 NaN                                         Stoke City
#
#                         away_club_name aggregate   competition_type
# 0                    FK Spartak Moskva       2:1    domestic_league
# 1                           Amkar Perm       0:2    domestic_league
# 2                     FK Dinamo Moskva       0:2    domestic_league
# 3                       FC Rubin Kazan       1:0    domestic_league
# 4      Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                ...       ...                ...
# 65211                              NaN       2:0  international_cup
# 65212                              NaN       6:0       domestic_cup
# 65213                              NaN       3:0  international_cup
# 65214                              NaN       6:1              other
# 65215                              NaN       3:1       domestic_cup
#
# [65216 rows x 23 columns]

# %%
games_df.head(10)
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 1  2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2  2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 3  2222664            RU1    2012   8. Matchday  2012-09-15           932
# 4  2222683            RU1    2012  12. Matchday  2012-10-22          2696
# 5  2222685            RU1    2012  19. Matchday  2012-12-10          2698
# 6  2222734            RU1    2012  19. Matchday  2012-12-07          1083
# 7  2222735            RU1    2012  18. Matchday  2012-12-02          2700
# 8  2222739            RU1    2012  22. Matchday  2013-03-31         16704
# 9  2222775            RU1    2012  28. Matchday  2013-05-12          3725
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0           232                2                1                 2.0  ...
# 1          4128                0                2                11.0  ...
# 2           121                0                2                 2.0  ...
# 3          2698                1                0                 5.0  ...
# 4         12438                0                1                11.0  ...
# 5           232                0                1                 7.0  ...
# 6         16704                2                3                11.0  ...
# 7          2410                2                0                 1.0  ...
# 8          2700                4                0                 8.0  ...
# 9          2700                1                0                 8.0  ...
#
#                   stadium attendance               referee  \
# 0            Akhmat-Arena    21700.0  Vladislav Bezborodov
# 1               Metallurg    11400.0         Sergey Ivanov
# 2            Arena Khimki    12000.0        Sergey Karasev
# 3               RZD Arena    11408.0        Sergey Karasev
# 4               Metallurg     7534.0     Timur Arslanbekov
# 5  Central Stadium  Kazan     8384.0  Vladislav Bezborodov
# 6                 Olimp-2     5700.0      Sergey Kuznetsov
# 7                  Dinamo    15500.0  Vladislav Bezborodov
# 8                   Kuban    18800.0      Aleksey Nikolaev
# 9            Akhmat-Arena    22000.0        Vitali Meshkov
#
#                                                  url  home_club_formation  \
# 0  https://www.transfermarkt.co.uk/terek-grozny_s...                  NaN
# 1  https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# 2  https://www.transfermarkt.co.uk/cska-moscow_di...                  NaN
# 3  https://www.transfermarkt.co.uk/lokomotiv-mosc...                  NaN
# 4  https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# 5  https://www.transfermarkt.co.uk/rubin-kazan_sp...                  NaN
# 6  https://www.transfermarkt.co.uk/fk-rostov_fk-k...                  NaN
# 7  https://www.transfermarkt.co.uk/anzhi-makhachk...                  NaN
# 8  https://www.transfermarkt.co.uk/fk-krasnodar_a...                  NaN
# 9  https://www.transfermarkt.co.uk/terek-grozny_a...                  NaN
#
#   away_club_formation                      home_club_name  \
# 0                 NaN                   RFK Akhmat Grozny
# 1                 NaN           PFK Krylya Sovetov Samara
# 2                 NaN                     PFK CSKA Moskva
# 3                 NaN  Футбольный клуб "Локомотив" Москва
# 4                 NaN           PFK Krylya Sovetov Samara
# 5                 NaN                      FC Rubin Kazan
# 6                 NaN                           FK Rostov
# 7                 NaN          Anzhi Makhachkala ( -2022)
# 8                 NaN                        FK Krasnodar
# 9                 NaN                   RFK Akhmat Grozny
#
#                     away_club_name aggregate competition_type
# 0                FK Spartak Moskva       2:1  domestic_league
# 1                       Amkar Perm       0:2  domestic_league
# 2                 FK Dinamo Moskva       0:2  domestic_league
# 3                   FC Rubin Kazan       1:0  domestic_league
# 4  Volga Nizhniy Novgorod (- 2016)       0:1  domestic_league
# 5                FK Spartak Moskva       0:1  domestic_league
# 6                     FK Krasnodar       2:3  domestic_league
# 7                  PFK CSKA Moskva       2:0  domestic_league
# 8       Anzhi Makhachkala ( -2022)       4:0  domestic_league
# 9       Anzhi Makhachkala ( -2022)       1:0  domestic_league
#
# [10 rows x 23 columns]

# %%
games_df = games_df.set_index('game_id')
games_df.head(10)
# Out:
#         competition_id  season         round        date  home_club_id  \
# game_id
# 2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 2222664            RU1    2012   8. Matchday  2012-09-15           932
# 2222683            RU1    2012  12. Matchday  2012-10-22          2696
# 2222685            RU1    2012  19. Matchday  2012-12-10          2698
# 2222734            RU1    2012  19. Matchday  2012-12-07          1083
# 2222735            RU1    2012  18. Matchday  2012-12-02          2700
# 2222739            RU1    2012  22. Matchday  2013-03-31         16704
# 2222775            RU1    2012  28. Matchday  2013-05-12          3725
#
#          away_club_id  home_club_goals  away_club_goals  home_club_position  \
# game_id
# 2222597           232                2                1                 2.0
# 2222627          4128                0                2                11.0
# 2222658           121                0                2                 2.0
# 2222664          2698                1                0                 5.0
# 2222683         12438                0                1                11.0
# 2222685           232                0                1                 7.0
# 2222734         16704                2                3                11.0
# 2222735          2410                2                0                 1.0
# 2222739          2700                4                0                 8.0
# 2222775          2700                1                0                 8.0
#
#          away_club_position  ...                 stadium attendance  \
# game_id                      ...
# 2222597                 5.0  ...            Akhmat-Arena    21700.0
# 2222627                10.0  ...               Metallurg    11400.0
# 2222658                13.0  ...            Arena Khimki    12000.0
# 2222664                 8.0  ...               RZD Arena    11408.0
# 2222683                16.0  ...               Metallurg     7534.0
# 2222685                 5.0  ...  Central Stadium  Kazan     8384.0
# 2222734                10.0  ...                 Olimp-2     5700.0
# 2222735                 2.0  ...                  Dinamo    15500.0
# 2222739                 3.0  ...                   Kuban    18800.0
# 2222775                 3.0  ...            Akhmat-Arena    22000.0
#
#                       referee  \
# game_id
# 2222597  Vladislav Bezborodov
# 2222627         Sergey Ivanov
# 2222658        Sergey Karasev
# 2222664        Sergey Karasev
# 2222683     Timur Arslanbekov
# 2222685  Vladislav Bezborodov
# 2222734      Sergey Kuznetsov
# 2222735  Vladislav Bezborodov
# 2222739      Aleksey Nikolaev
# 2222775        Vitali Meshkov
#
#                                                        url  \
# game_id
# 2222597  https://www.transfermarkt.co.uk/terek-grozny_s...
# 2222627  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222658  https://www.transfermarkt.co.uk/cska-moscow_di...
# 2222664  https://www.transfermarkt.co.uk/lokomotiv-mosc...
# 2222683  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222685  https://www.transfermarkt.co.uk/rubin-kazan_sp...
# 2222734  https://www.transfermarkt.co.uk/fk-rostov_fk-k...
# 2222735  https://www.transfermarkt.co.uk/anzhi-makhachk...
# 2222739  https://www.transfermarkt.co.uk/fk-krasnodar_a...
# 2222775  https://www.transfermarkt.co.uk/terek-grozny_a...
#
#         home_club_formation away_club_formation  \
# game_id
# 2222597                 NaN                 NaN
# 2222627                 NaN                 NaN
# 2222658                 NaN                 NaN
# 2222664                 NaN                 NaN
# 2222683                 NaN                 NaN
# 2222685                 NaN                 NaN
# 2222734                 NaN                 NaN
# 2222735                 NaN                 NaN
# 2222739                 NaN                 NaN
# 2222775                 NaN                 NaN
#
#                              home_club_name                   away_club_name  \
# game_id
# 2222597                   RFK Akhmat Grozny                FK Spartak Moskva
# 2222627           PFK Krylya Sovetov Samara                       Amkar Perm
# 2222658                     PFK CSKA Moskva                 FK Dinamo Moskva
# 2222664  Футбольный клуб "Локомотив" Москва                   FC Rubin Kazan
# 2222683           PFK Krylya Sovetov Samara  Volga Nizhniy Novgorod (- 2016)
# 2222685                      FC Rubin Kazan                FK Spartak Moskva
# 2222734                           FK Rostov                     FK Krasnodar
# 2222735          Anzhi Makhachkala ( -2022)                  PFK CSKA Moskva
# 2222739                        FK Krasnodar       Anzhi Makhachkala ( -2022)
# 2222775                   RFK Akhmat Grozny       Anzhi Makhachkala ( -2022)
#
#         aggregate competition_type
# game_id
# 2222597       2:1  domestic_league
# 2222627       0:2  domestic_league
# 2222658       0:2  domestic_league
# 2222664       1:0  domestic_league
# 2222683       0:1  domestic_league
# 2222685       0:1  domestic_league
# 2222734       2:3  domestic_league
# 2222735       2:0  domestic_league
# 2222739       4:0  domestic_league
# 2222775       1:0  domestic_league
#
# [10 rows x 22 columns]

# %%
games_df.columns
# Out:
# Index(['competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
# handling NA values
games_df.isna().sum()
# Out:
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  0
# away_club_id                  0
# home_club_goals               0
# away_club_goals               0
# home_club_position        19454
# away_club_position        19454
# home_club_manager_name      742
# away_club_manager_name      742
# stadium                     211
# attendance                 9512
# referee                     594
# url                           0
# home_club_formation       62347
# away_club_formation       62328
# home_club_name            11252
# away_club_name            10049
# aggregate                     0
# competition_type              0
# dtype: int64

# %%
# Togliere le righe in cui tutti i valori delle colonne elencate sono NaN
games_df = games_df.dropna(subset=['home_club_position','away_club_position','home_club_manager_name','away_club_manager_name','stadium','attendance','referee','home_club_formation','away_club_formation'], how='all')

games_df
# Out:
#         competition_id  season                     round        date  \
# game_id
# 2222597            RU1    2012               6. Matchday  2012-08-25
# 2222627            RU1    2012               5. Matchday  2012-08-20
# 2222658            RU1    2012              10. Matchday  2012-09-30
# 2222664            RU1    2012               8. Matchday  2012-09-15
# 2222683            RU1    2012              12. Matchday  2012-10-22
# ...                ...     ...                       ...         ...
# 2367292             EL    2013                   Group B  2013-11-07
# 2629035            NLP    2015               Third Round  2015-10-27
# 3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 4164101            CGB    2023              Second Round  2023-08-29
# 4013659            FAC    2022              Fourth Round  2023-01-29
#
#          home_club_id  away_club_id  home_club_goals  away_club_goals  \
# game_id
# 2222597          3725           232                2                1
# 2222627          2696          4128                0                2
# 2222658          2410           121                0                2
# 2222664           932          2698                1                0
# 2222683          2696         12438                0                1
# ...               ...           ...              ...              ...
# 2367292           383           419                2                0
# 2629035           383         16866                6                0
# 3092951           383           713                3                0
# 4164101           512          1194                6                1
# 4013659           512          3684                3                1
#
#          home_club_position  away_club_position  ...          stadium  \
# game_id                                          ...
# 2222597                 2.0                 5.0  ...     Akhmat-Arena
# 2222627                11.0                10.0  ...        Metallurg
# 2222658                 2.0                13.0  ...     Arena Khimki
# 2222664                 5.0                 8.0  ...        RZD Arena
# 2222683                11.0                16.0  ...        Metallurg
# ...                     ...                 ...  ...              ...
# 2367292                 NaN                 NaN  ...  Philips Stadion
# 2629035                 NaN                 NaN  ...  Philips Stadion
# 3092951                 NaN                 NaN  ...  Philips Stadion
# 4164101                 NaN                 NaN  ...   bet365 Stadium
# 4013659                 NaN                 NaN  ...   bet365 Stadium
#
#         attendance               referee  \
# game_id
# 2222597    21700.0  Vladislav Bezborodov
# 2222627    11400.0         Sergey Ivanov
# 2222658    12000.0        Sergey Karasev
# 2222664    11408.0        Sergey Karasev
# 2222683     7534.0     Timur Arslanbekov
# ...            ...                   ...
# 2367292    10000.0        Cristian Balaj
# 2629035    31000.0       Allard Lindhout
# 3092951    34200.0        Anthony Taylor
# 4164101     9410.0     Michael Salisbury
# 4013659    14392.0            David Webb
#
#                                                        url  \
# game_id
# 2222597  https://www.transfermarkt.co.uk/terek-grozny_s...
# 2222627  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222658  https://www.transfermarkt.co.uk/cska-moscow_di...
# 2222664  https://www.transfermarkt.co.uk/lokomotiv-mosc...
# 2222683  https://www.transfermarkt.co.uk/krylya-sovetov...
# ...                                                    ...
# 2367292  https://www.transfermarkt.co.uk/spielbericht/i...
# 2629035  https://www.transfermarkt.co.uk/spielbericht/i...
# 3092951  https://www.transfermarkt.co.uk/spielbericht/i...
# 4164101  https://www.transfermarkt.co.uk/spielbericht/i...
# 4013659  https://www.transfermarkt.co.uk/spielbericht/i...
#
#         home_club_formation away_club_formation  \
# game_id
# 2222597                 NaN                 NaN
# 2222627                 NaN                 NaN
# 2222658                 NaN                 NaN
# 2222664                 NaN                 NaN
# 2222683                 NaN                 NaN
# ...                     ...                 ...
# 2367292                 NaN                 NaN
# 2629035                 NaN                 NaN
# 3092951                 NaN                 NaN
# 4164101             4-2-3-1             4-2-3-1
# 4013659                 NaN                 NaN
#
#                                             home_club_name  \
# game_id
# 2222597                                  RFK Akhmat Grozny
# 2222627                          PFK Krylya Sovetov Samara
# 2222658                                    PFK CSKA Moskva
# 2222664                 Футбольный клуб "Локомотив" Москва
# 2222683                          PFK Krylya Sovetov Samara
# ...                                                    ...
# 2367292  Eindhovense Voetbalvereniging Philips Sport Ve...
# 2629035  Eindhovense Voetbalvereniging Philips Sport Ve...
# 3092951  Eindhovense Voetbalvereniging Philips Sport Ve...
# 4164101                                         Stoke City
# 4013659                                         Stoke City
#
#                           away_club_name aggregate   competition_type
# game_id
# 2222597                FK Spartak Moskva       2:1    domestic_league
# 2222627                       Amkar Perm       0:2    domestic_league
# 2222658                 FK Dinamo Moskva       0:2    domestic_league
# 2222664                   FC Rubin Kazan       1:0    domestic_league
# 2222683  Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                  ...       ...                ...
# 2367292                              NaN       2:0  international_cup
# 2629035                              NaN       6:0       domestic_cup
# 3092951                              NaN       3:0  international_cup
# 4164101                              NaN       6:1              other
# 4013659                              NaN       3:1       domestic_cup
#
# [65197 rows x 22 columns]

# %%
# Togliere le righe che non hanno nè squadra di casa mè squadra di trasferta
games_df = games_df.dropna(subset=['home_club_name','away_club_name'], how='all')

games_df['home_club_name'].isna().sum()
# Out:
# 3519

# %%
games_df.loc[games_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [competition_id, season, round, date, home_club_id, away_club_id, home_club_goals, away_club_goals, home_club_position, away_club_position, home_club_manager_name, away_club_manager_name, stadium, attendance, referee, url, home_club_formation, away_club_formation, home_club_name, away_club_name, aggregate, competition_type]
# Index: []
#
# [0 rows x 22 columns]

# %%
games_df.dtypes
# Out:
# competition_id             object
# season                      int64
# round                      object
# date                       object
# home_club_id                int64
# away_club_id                int64
# home_club_goals             int64
# away_club_goals             int64
# home_club_position        float64
# away_club_position        float64
# home_club_manager_name     object
# away_club_manager_name     object
# stadium                    object
# attendance                float64
# referee                    object
# url                        object
# home_club_formation        object
# away_club_formation        object
# home_club_name             object
# away_club_name             object
# aggregate                  object
# competition_type           object
# dtype: object

# %%
games_df['date'] = pd.to_datetime(games_df['date']).dt.strftime('%d-%m-%Y')

games_df
# Out:
# C:\Users\ricca\AppData\Local\Temp\ipykernel_5624\46816557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_df['date'] = pd.to_datetime(games_df['date']).dt.strftime('%d-%m-%Y')
#         competition_id  season                     round        date  \
# game_id
# 2222597            RU1    2012               6. Matchday  25-08-2012
# 2222627            RU1    2012               5. Matchday  20-08-2012
# 2222658            RU1    2012              10. Matchday  30-09-2012
# 2222664            RU1    2012               8. Matchday  15-09-2012
# 2222683            RU1    2012              12. Matchday  22-10-2012
# ...                ...     ...                       ...         ...
# 2367292             EL    2013                   Group B  07-11-2013
# 2629035            NLP    2015               Third Round  27-10-2015
# 3092951            CLQ    2018  Qualifying Round 2nd leg  29-08-2018
# 4164101            CGB    2023              Second Round  29-08-2023
# 4013659            FAC    2022              Fourth Round  29-01-2023
#
#          home_club_id  away_club_id  home_club_goals  away_club_goals  \
# game_id
# 2222597          3725           232                2                1
# 2222627          2696          4128                0                2
# 2222658          2410           121                0                2
# 2222664           932          2698                1                0
# 2222683          2696         12438                0                1
# ...               ...           ...              ...              ...
# 2367292           383           419                2                0
# 2629035           383         16866                6                0
# 3092951           383           713                3                0
# 4164101           512          1194                6                1
# 4013659           512          3684                3                1
#
#          home_club_position  away_club_position  ...          stadium  \
# game_id                                          ...
# 2222597                 2.0                 5.0  ...     Akhmat-Arena
# 2222627                11.0                10.0  ...        Metallurg
# 2222658                 2.0                13.0  ...     Arena Khimki
# 2222664                 5.0                 8.0  ...        RZD Arena
# 2222683                11.0                16.0  ...        Metallurg
# ...                     ...                 ...  ...              ...
# 2367292                 NaN                 NaN  ...  Philips Stadion
# 2629035                 NaN                 NaN  ...  Philips Stadion
# 3092951                 NaN                 NaN  ...  Philips Stadion
# 4164101                 NaN                 NaN  ...   bet365 Stadium
# 4013659                 NaN                 NaN  ...   bet365 Stadium
#
#         attendance               referee  \
# game_id
# 2222597    21700.0  Vladislav Bezborodov
# 2222627    11400.0         Sergey Ivanov
# 2222658    12000.0        Sergey Karasev
# 2222664    11408.0        Sergey Karasev
# 2222683     7534.0     Timur Arslanbekov
# ...            ...                   ...
# 2367292    10000.0        Cristian Balaj
# 2629035    31000.0       Allard Lindhout
# 3092951    34200.0        Anthony Taylor
# 4164101     9410.0     Michael Salisbury
# 4013659    14392.0            David Webb
#
#                                                        url  \
# game_id
# 2222597  https://www.transfermarkt.co.uk/terek-grozny_s...
# 2222627  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222658  https://www.transfermarkt.co.uk/cska-moscow_di...
# 2222664  https://www.transfermarkt.co.uk/lokomotiv-mosc...
# 2222683  https://www.transfermarkt.co.uk/krylya-sovetov...
# ...                                                    ...
# 2367292  https://www.transfermarkt.co.uk/spielbericht/i...
# 2629035  https://www.transfermarkt.co.uk/spielbericht/i...
# 3092951  https://www.transfermarkt.co.uk/spielbericht/i...
# 4164101  https://www.transfermarkt.co.uk/spielbericht/i...
# 4013659  https://www.transfermarkt.co.uk/spielbericht/i...
#
#         home_club_formation away_club_formation  \
# game_id
# 2222597                 NaN                 NaN
# 2222627                 NaN                 NaN
# 2222658                 NaN                 NaN
# 2222664                 NaN                 NaN
# 2222683                 NaN                 NaN
# ...                     ...                 ...
# 2367292                 NaN                 NaN
# 2629035                 NaN                 NaN
# 3092951                 NaN                 NaN
# 4164101             4-2-3-1             4-2-3-1
# 4013659                 NaN                 NaN
#
#                                             home_club_name  \
# game_id
# 2222597                                  RFK Akhmat Grozny
# 2222627                          PFK Krylya Sovetov Samara
# 2222658                                    PFK CSKA Moskva
# 2222664                 Футбольный клуб "Локомотив" Москва
# 2222683                          PFK Krylya Sovetov Samara
# ...                                                    ...
# 2367292  Eindhovense Voetbalvereniging Philips Sport Ve...
# 2629035  Eindhovense Voetbalvereniging Philips Sport Ve...
# 3092951  Eindhovense Voetbalvereniging Philips Sport Ve...
# 4164101                                         Stoke City
# 4013659                                         Stoke City
#
#                           away_club_name aggregate   competition_type
# game_id
# 2222597                FK Spartak Moskva       2:1    domestic_league
# 2222627                       Amkar Perm       0:2    domestic_league
# 2222658                 FK Dinamo Moskva       0:2    domestic_league
# 2222664                   FC Rubin Kazan       1:0    domestic_league
# 2222683  Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                  ...       ...                ...
# 2367292                              NaN       2:0  international_cup
# 2629035                              NaN       6:0       domestic_cup
# 3092951                              NaN       3:0  international_cup
# 4164101                              NaN       6:1              other
# 4013659                              NaN       3:1       domestic_cup
#
# [57483 rows x 22 columns]

# %% [markdown]
# # Data Analysis & Visualization

# %%
#making a dataframe subset and reordering columns
games_df = games_df [
    ['competition_id', 
     'season', 
     'round', 
     'date', 
     'home_club_id',
     'home_club_name',
     'home_club_goals',
     'home_club_position', 
     'home_club_manager_name',
     'home_club_formation', 
     'away_club_id',  
     'away_club_name',
     'away_club_goals',
     'away_club_position', 
     'away_club_manager_name', 
     'away_club_formation', 
     'stadium', 
     'attendance', 
     'referee', 
     #'url',
     'aggregate', 
     'competition_type']
]

games_df.sort_values("home_club_name", ascending = True)
# Out:
#         competition_id  season              round        date  home_club_id  \
# game_id
# 3203540             L1    2019       12. Matchday  23-11-2019            89
# 3839027             L1    2022        1. Matchday  06-08-2022            89
# 4095986             L1    2023        3. Matchday  03-09-2023            89
# 3203459             L1    2019        3. Matchday  31-08-2019            89
# 3203432             L1    2019        1. Matchday  18-08-2019            89
# ...                ...     ...                ...         ...           ...
# 4190054            NLP    2023        First Round  31-10-2023          7110
# 4157255            DKP    2023       Second Round  06-09-2023         25495
# 4088601            DFB    2023        First Round  12-08-2023           834
# 4171268             CL    2023            Group D  03-10-2023           409
# 4135637            CLQ    2023  3rd round 2nd leg  15-08-2023           122
#
#              home_club_name  home_club_goals  home_club_position  \
# game_id
# 3203540  1. FC Union Berlin                2                11.0
# 3839027  1. FC Union Berlin                3                 3.0
# 4095986  1. FC Union Berlin                0                 5.0
# 3203459  1. FC Union Berlin                3                11.0
# 3203432  1. FC Union Berlin                0                18.0
# ...                     ...              ...                 ...
# 4190054                 NaN                1                 NaN
# 4157255                 NaN                0                 NaN
# 4088601                 NaN                0                 NaN
# 4171268                 NaN                0                 NaN
# 4135637                 NaN                1                 NaN
#
#         home_club_manager_name home_club_formation  ...  \
# game_id                                             ...
# 3203540            Urs Fischer                 NaN  ...
# 3839027            Urs Fischer                 NaN  ...
# 4095986            Urs Fischer               3-4-3  ...
# 3203459            Urs Fischer                 NaN  ...
# 3203432            Urs Fischer                 NaN  ...
# ...                        ...                 ...  ...
# 4190054   Thomas Duivenvoorden     4-3-3 Defending  ...
# 4157255              Jes Bekke                 NaN  ...
# 4088601           Martin Braun               3-5-2  ...
# 4171268        Gerhard Struber             4-3-1-2  ...
# 4135637        Christian Ilzer       4-4-2 Diamond  ...
#
#                                             away_club_name away_club_goals  \
# game_id
# 3203540  Borussia Verein für Leibesübungen 1900 Mönchen...               0
# 3839027                                         Hertha BSC               1
# 4095986                             RasenBallsport Leipzig               3
# 3203459                                  Borussia Dortmund               1
# 3203432                             RasenBallsport Leipzig               4
# ...                                                    ...             ...
# 4190054                                          NAC Breda               0
# 4157255                                           Hobro IK               2
# 4088601          Verein für Bewegungsspiele Stuttgart 1893               4
# 4171268                     Real Sociedad de Fútbol S.A.D.               2
# 4135637  Eindhovense Voetbalvereniging Philips Sport Ve...               3
#
#          away_club_position  away_club_manager_name away_club_formation  \
# game_id
# 3203540                 1.0              Marco Rose                 NaN
# 3839027                15.0          Sandro Schwarz                 NaN
# 4095986                 4.0              Marco Rose               4-4-2
# 3203459                 5.0            Lucien Favre                 NaN
# 3203432                 2.0       Julian Nagelsmann                 NaN
# ...                     ...                     ...                 ...
# 4190054                 NaN    Jean-Paul van Gastel             3-4-1-2
# 4157255                 NaN          Martin Thomsen          3-5-2 flat
# 4088601                 NaN        Sebastian Hoeneß             4-2-3-1
# 4171268                 NaN         Imanol Alguacil               4-4-2
# 4135637                 NaN              Peter Bosz     4-3-3 Attacking
#
#                                 stadium attendance  \
# game_id
# 3203540  Stadion An der Alten Försterei    22012.0
# 3839027  Stadion An der Alten Försterei    22012.0
# 4095986  Stadion An der Alten Försterei    22012.0
# 3203459  Stadion An der Alten Försterei    22012.0
# 3203432  Stadion An der Alten Försterei    22012.0
# ...                                 ...        ...
# 4190054            Sportpark Nieuw Zuid        NaN
# 4157255                 Mosevej Stadion        NaN
# 4088601       Stadion an der Kreuzeiche    13400.0
# 4171268         Red Bull Arena Salzburg    28227.0
# 4135637                    Merkur Arena    12571.0
#
#                             referee aggregate   competition_type
# game_id
# 3203540             Dr. Felix Brych       2:0    domestic_league
# 3839027                 Marco Fritz       3:1    domestic_league
# 4095986             Daniel Schlager       0:3    domestic_league
# 3203459             Dr. Felix Brych       3:1    domestic_league
# 3203432              Markus Schmidt       0:4    domestic_league
# ...                             ...       ...                ...
# 4190054          Edwin van de Graaf       1:0       domestic_cup
# 4157255  Jörgen Daugbjerg Burchardt       0:2       domestic_cup
# 4088601           Dr. Robert Kampka       0:4       domestic_cup
# 4171268          Bartosz Frankowski       0:2  international_cup
# 4135637            Srdjan Jovanovic       1:3  international_cup
#
# [57483 rows x 21 columns]

# %%
games_df = games_df.rename(columns={'aggregate':'score'})

# %%
games_df
# Out:
#         competition_id  season                     round        date  \
# game_id
# 2222597            RU1    2012               6. Matchday  25-08-2012
# 2222627            RU1    2012               5. Matchday  20-08-2012
# 2222658            RU1    2012              10. Matchday  30-09-2012
# 2222664            RU1    2012               8. Matchday  15-09-2012
# 2222683            RU1    2012              12. Matchday  22-10-2012
# ...                ...     ...                       ...         ...
# 2367292             EL    2013                   Group B  07-11-2013
# 2629035            NLP    2015               Third Round  27-10-2015
# 3092951            CLQ    2018  Qualifying Round 2nd leg  29-08-2018
# 4164101            CGB    2023              Second Round  29-08-2023
# 4013659            FAC    2022              Fourth Round  29-01-2023
#
#          home_club_id                                     home_club_name  \
# game_id
# 2222597          3725                                  RFK Akhmat Grozny
# 2222627          2696                          PFK Krylya Sovetov Samara
# 2222658          2410                                    PFK CSKA Moskva
# 2222664           932                 Футбольный клуб "Локомотив" Москва
# 2222683          2696                          PFK Krylya Sovetov Samara
# ...               ...                                                ...
# 2367292           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 2629035           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 3092951           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 4164101           512                                         Stoke City
# 4013659           512                                         Stoke City
#
#          home_club_goals  home_club_position home_club_manager_name  \
# game_id
# 2222597                2                 2.0   Stanislav Cherchesov
# 2222627                0                11.0         Andrey Kobelev
# 2222658                0                 2.0         Leonid Slutski
# 2222664                1                 5.0           Slaven Bilic
# 2222683                0                11.0         Andrey Kobelev
# ...                  ...                 ...                    ...
# 2367292                2                 NaN           Phillip Cocu
# 2629035                6                 NaN           Phillip Cocu
# 3092951                3                 NaN        Mark van Bommel
# 4164101                6                 NaN              Alex Neil
# 4013659                3                 NaN              Alex Neil
#
#         home_club_formation  ...                   away_club_name  \
# game_id                      ...
# 2222597                 NaN  ...                FK Spartak Moskva
# 2222627                 NaN  ...                       Amkar Perm
# 2222658                 NaN  ...                 FK Dinamo Moskva
# 2222664                 NaN  ...                   FC Rubin Kazan
# 2222683                 NaN  ...  Volga Nizhniy Novgorod (- 2016)
# ...                     ...  ...                              ...
# 2367292                 NaN  ...                              NaN
# 2629035                 NaN  ...                              NaN
# 3092951                 NaN  ...                              NaN
# 4164101             4-2-3-1  ...                              NaN
# 4013659                 NaN  ...                              NaN
#
#         away_club_goals  away_club_position  away_club_manager_name  \
# game_id
# 2222597               1                 5.0              Unai Emery
# 2222627               2                10.0           Rustem Khuzin
# 2222658               2                13.0            Dan Petrescu
# 2222664               0                 8.0          Kurban Berdyev
# 2222683               1                16.0         Gadzhi Gadzhiev
# ...                 ...                 ...                     ...
# 2367292               0                 NaN             Zoran Mamic
# 2629035               0                 NaN        Hennie in 't Hof
# 3092951               0                 NaN            Aleksey Baga
# 4164101               1                 NaN             Matt Taylor
# 4013659               1                 NaN             Steve Evans
#
#         away_club_formation          stadium attendance               referee  \
# game_id
# 2222597                 NaN     Akhmat-Arena    21700.0  Vladislav Bezborodov
# 2222627                 NaN        Metallurg    11400.0         Sergey Ivanov
# 2222658                 NaN     Arena Khimki    12000.0        Sergey Karasev
# 2222664                 NaN        RZD Arena    11408.0        Sergey Karasev
# 2222683                 NaN        Metallurg     7534.0     Timur Arslanbekov
# ...                     ...              ...        ...                   ...
# 2367292                 NaN  Philips Stadion    10000.0        Cristian Balaj
# 2629035                 NaN  Philips Stadion    31000.0       Allard Lindhout
# 3092951                 NaN  Philips Stadion    34200.0        Anthony Taylor
# 4164101             4-2-3-1   bet365 Stadium     9410.0     Michael Salisbury
# 4013659                 NaN   bet365 Stadium    14392.0            David Webb
#
#         score   competition_type
# game_id
# 2222597   2:1    domestic_league
# 2222627   0:2    domestic_league
# 2222658   0:2    domestic_league
# 2222664   1:0    domestic_league
# 2222683   0:1    domestic_league
# ...       ...                ...
# 2367292   2:0  international_cup
# 2629035   6:0       domestic_cup
# 3092951   3:0  international_cup
# 4164101   6:1              other
# 4013659   3:1       domestic_cup
#
# [57483 rows x 21 columns]

# %%
# checking variable home_club_name
games_df['away_club_name'].describe()
# Out:
# count                          55161
# unique                           426
# top       Sevilla Fútbol Club S.A.D.
# freq                             323
# Name: away_club_name, dtype: object

# %%
# check for goal outliers
ax = games_df.boxplot(column='home_club_goals')
ax.set_title('Numbers of goals in Home Club')
plt.show()

# %%
# goal squadra in casa
games_df['home_club_goals'].value_counts().plot(kind='bar', title="Numero di goal (Casa)")
plt.xlabel('Goal Squadra in Casa')
plt.ylabel('Numero di partite')
plt.xticks(rotation=0)
plt.show()

# %%
# goal segnati Casa

home_goal_counts = games_df['home_club_goals'].value_counts().sort_index()
total_games = len(games_df)
home_goal_percentages = (home_goal_counts / total_games) * 100


plt.figure(figsize=(10, 6))
ax = home_goal_percentages.plot(kind='bar', title="Numero di goal (Casa) in percentuale")

for i, percentage in enumerate(home_goal_percentages):
    ax.text(i, percentage + 0.5, f'{percentage:.2f}%', ha='center')

plt.xlabel('Goal Squadra in Casa')
plt.ylabel('Percentuale di partite (%)')
plt.xticks(rotation=0)
plt.ylim(0, 40)
plt.show()

# %%
# goal squadra Trasferta

away_goal_counts = games_df['away_club_goals'].value_counts().sort_index()
total_games = len(games_df)
away_goal_percentages = (away_goal_counts / total_games) * 100


plt.figure(figsize=(10, 6))
ax = away_goal_percentages.plot(kind='bar', title="Numero di goal (Trasferta) in percentuale")

for i, percentage in enumerate(away_goal_percentages):
    ax.text(i, percentage + 0.5, f'{percentage:.2f}%', ha='center')

plt.xlabel('Goal Squadra in Trasferta')
plt.ylabel('Percentuale di partite (%)')
plt.xticks(rotation=0)
plt.ylim(0, 40)
plt.show()

# %%
game_results = games_df['score'].value_counts()

sns.barplot(data=game_results.head(20), orient='h')
plt.title("Risultati più frequenti")
plt.xlabel('Numero di partite')
plt.ylabel('Risultato')
plt.show()

# %%
games_df
# Out:
#         competition_id  season                     round        date  \
# game_id
# 2222597            RU1    2012               6. Matchday  25-08-2012
# 2222627            RU1    2012               5. Matchday  20-08-2012
# 2222658            RU1    2012              10. Matchday  30-09-2012
# 2222664            RU1    2012               8. Matchday  15-09-2012
# 2222683            RU1    2012              12. Matchday  22-10-2012
# ...                ...     ...                       ...         ...
# 2367292             EL    2013                   Group B  07-11-2013
# 2629035            NLP    2015               Third Round  27-10-2015
# 3092951            CLQ    2018  Qualifying Round 2nd leg  29-08-2018
# 4164101            CGB    2023              Second Round  29-08-2023
# 4013659            FAC    2022              Fourth Round  29-01-2023
#
#          home_club_id                                     home_club_name  \
# game_id
# 2222597          3725                                  RFK Akhmat Grozny
# 2222627          2696                          PFK Krylya Sovetov Samara
# 2222658          2410                                    PFK CSKA Moskva
# 2222664           932                 Футбольный клуб "Локомотив" Москва
# 2222683          2696                          PFK Krylya Sovetov Samara
# ...               ...                                                ...
# 2367292           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 2629035           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 3092951           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 4164101           512                                         Stoke City
# 4013659           512                                         Stoke City
#
#          home_club_goals  home_club_position home_club_manager_name  \
# game_id
# 2222597                2                 2.0   Stanislav Cherchesov
# 2222627                0                11.0         Andrey Kobelev
# 2222658                0                 2.0         Leonid Slutski
# 2222664                1                 5.0           Slaven Bilic
# 2222683                0                11.0         Andrey Kobelev
# ...                  ...                 ...                    ...
# 2367292                2                 NaN           Phillip Cocu
# 2629035                6                 NaN           Phillip Cocu
# 3092951                3                 NaN        Mark van Bommel
# 4164101                6                 NaN              Alex Neil
# 4013659                3                 NaN              Alex Neil
#
#         home_club_formation  ...                   away_club_name  \
# game_id                      ...
# 2222597                 NaN  ...                FK Spartak Moskva
# 2222627                 NaN  ...                       Amkar Perm
# 2222658                 NaN  ...                 FK Dinamo Moskva
# 2222664                 NaN  ...                   FC Rubin Kazan
# 2222683                 NaN  ...  Volga Nizhniy Novgorod (- 2016)
# ...                     ...  ...                              ...
# 2367292                 NaN  ...                              NaN
# 2629035                 NaN  ...                              NaN
# 3092951                 NaN  ...                              NaN
# 4164101             4-2-3-1  ...                              NaN
# 4013659                 NaN  ...                              NaN
#
#         away_club_goals  away_club_position  away_club_manager_name  \
# game_id
# 2222597               1                 5.0              Unai Emery
# 2222627               2                10.0           Rustem Khuzin
# 2222658               2                13.0            Dan Petrescu
# 2222664               0                 8.0          Kurban Berdyev
# 2222683               1                16.0         Gadzhi Gadzhiev
# ...                 ...                 ...                     ...
# 2367292               0                 NaN             Zoran Mamic
# 2629035               0                 NaN        Hennie in 't Hof
# 3092951               0                 NaN            Aleksey Baga
# 4164101               1                 NaN             Matt Taylor
# 4013659               1                 NaN             Steve Evans
#
#         away_club_formation          stadium attendance               referee  \
# game_id
# 2222597                 NaN     Akhmat-Arena    21700.0  Vladislav Bezborodov
# 2222627                 NaN        Metallurg    11400.0         Sergey Ivanov
# 2222658                 NaN     Arena Khimki    12000.0        Sergey Karasev
# 2222664                 NaN        RZD Arena    11408.0        Sergey Karasev
# 2222683                 NaN        Metallurg     7534.0     Timur Arslanbekov
# ...                     ...              ...        ...                   ...
# 2367292                 NaN  Philips Stadion    10000.0        Cristian Balaj
# 2629035                 NaN  Philips Stadion    31000.0       Allard Lindhout
# 3092951                 NaN  Philips Stadion    34200.0        Anthony Taylor
# 4164101             4-2-3-1   bet365 Stadium     9410.0     Michael Salisbury
# 4013659                 NaN   bet365 Stadium    14392.0            David Webb
#
#         score   competition_type
# game_id
# 2222597   2:1    domestic_league
# 2222627   0:2    domestic_league
# 2222658   0:2    domestic_league
# 2222664   1:0    domestic_league
# 2222683   0:1    domestic_league
# ...       ...                ...
# 2367292   2:0  international_cup
# 2629035   6:0       domestic_cup
# 3092951   3:0  international_cup
# 4164101   6:1              other
# 4013659   3:1       domestic_cup
#
# [57483 rows x 21 columns]

# %%
# adding a column name for the national leagues

league_names = {
    'BE1': 'Belgian Jupiler Pro League',
    'DK1': 'Danish Superliga',
    'ES1': 'LaLiga',
    'FR1': 'Ligue 1',
    'GB1': 'Premier League',
    'GR1': 'Greece Super League 1',
    'IT1': 'Serie A',
    'L1': 'Bundesliga',
    'NL1': 'Eredivisie',
    'PO1': 'Liga Portugal',
    'RU1': 'Russian Premier Liga',
    'SC1': 'Scottish Premiership',
    'TR1': 'Turkish Super League',
    'UKR1': 'Ukrainian Premier Liga'
}

competitions_df.loc[competitions_df['sub_type'] == 'first_tier', 'competition_name'] = competitions_df['competition_id'].map(league_names)

# %%
# selecting only first tier leagues
competitions_df = competitions_df.dropna()
competitions_df
# Out:
#    competition_id      competition_code                  name    sub_type  \
# 7             DK1           superligaen           superligaen  first_tier
# 9             ES1                laliga                laliga  first_tier
# 10            FR1               ligue-1               ligue-1  first_tier
# 11            IT1               serie-a               serie-a  first_tier
# 12            NL1            eredivisie            eredivisie  first_tier
# 14            PO1    liga-portugal-bwin    liga-portugal-bwin  first_tier
# 16            GB1        premier-league        premier-league  first_tier
# 24           UKR1          premier-liga          premier-liga  first_tier
# 27            GR1        super-league-1        super-league-1  first_tier
# 28            TR1             super-lig             super-lig  first_tier
# 32             L1            bundesliga            bundesliga  first_tier
# 33            RU1          premier-liga          premier-liga  first_tier
# 34            SC1  scottish-premiership  scottish-premiership  first_tier
# 36            BE1    jupiler-pro-league    jupiler-pro-league  first_tier
#
#                type  country_id country_name domestic_league_code  \
# 7   domestic_league          39      Denmark                  DK1
# 9   domestic_league         157        Spain                  ES1
# 10  domestic_league          50       France                  FR1
# 11  domestic_league          75        Italy                  IT1
# 12  domestic_league         122  Netherlands                  NL1
# 14  domestic_league         136     Portugal                  PO1
# 16  domestic_league         189      England                  GB1
# 24  domestic_league         177      Ukraine                 UKR1
# 27  domestic_league          56       Greece                  GR1
# 28  domestic_league         174       Turkey                  TR1
# 32  domestic_league          40      Germany                   L1
# 33  domestic_league         141       Russia                  RU1
# 34  domestic_league         190     Scotland                  SC1
# 36  domestic_league          19      Belgium                  BE1
#
#    confederation                                                url  \
# 7         europa  https://www.transfermarkt.co.uk/superligaen/st...
# 9         europa  https://www.transfermarkt.co.uk/laliga/startse...
# 10        europa  https://www.transfermarkt.co.uk/ligue-1/starts...
# 11        europa  https://www.transfermarkt.co.uk/serie-a/starts...
# 12        europa  https://www.transfermarkt.co.uk/eredivisie/sta...
# 14        europa  https://www.transfermarkt.co.uk/liga-portugal-...
# 16        europa  https://www.transfermarkt.co.uk/premier-league...
# 24        europa  https://www.transfermarkt.co.uk/premier-liga/s...
# 27        europa  https://www.transfermarkt.co.uk/super-league-1...
# 28        europa  https://www.transfermarkt.co.uk/super-lig/star...
# 32        europa  https://www.transfermarkt.co.uk/bundesliga/sta...
# 33        europa  https://www.transfermarkt.co.uk/premier-liga/s...
# 34        europa  https://www.transfermarkt.co.uk/scottish-premi...
# 36        europa  https://www.transfermarkt.co.uk/jupiler-pro-le...
#
#               competition_name
# 7             Danish Superliga
# 9                       LaLiga
# 10                     Ligue 1
# 11                     Serie A
# 12                  Eredivisie
# 14               Liga Portugal
# 16              Premier League
# 24      Ukrainian Premier Liga
# 27       Greece Super League 1
# 28        Turkish Super League
# 32                  Bundesliga
# 33        Russian Premier Liga
# 34        Scottish Premiership
# 36  Belgian Jupiler Pro League

# %%
# Spettatori medi per ogni campionato

merged_df = pd.merge(games_df, competitions_df, on='competition_id', how='left')

avg_attendance_by_competition = (merged_df.groupby('competition_id')['attendance'].mean().reset_index()).sort_values(by='attendance', ascending=False)

# code by ChatGPT
mapping_name = competitions_df.set_index('competition_id')['competition_name'].to_dict()
avg_attendance_by_competition['competition_name'] = avg_attendance_by_competition['competition_id'].map(mapping_name)

sns.barplot(data=avg_attendance_by_competition, y='competition_name', x='attendance')
plt.title('Media di spettatori per ogni campionato')
plt.ylabel('')
plt.xlabel('Spettatori medi')
plt.show()

# %%
# Arbitri con il maggior numero di partite arbitrate
games_df.query('date > "01-01-2023"')

referee_matches = games_df.groupby('referee')['referee'].value_counts().reset_index(name='matches_officiated')

df_sorted = referee_matches.sort_values(by='matches_officiated', ascending=False).head(15)

# Disegna il grafico utilizzando Seaborn
sns.barplot(x='matches_officiated', y='referee', data=df_sorted)
plt.title('Arbitri con il maggior numero di partite arbitrate')
plt.ylabel('')
plt.xlabel('Numero di partite arbitrate')
plt.show()

# %%
# Partite con più spettatori (attendance)
df_sorted = games_df.sort_values(by='attendance', ascending=False).head(20)

df_sorted[['home_club_name','score','away_club_name','attendance','stadium','date']]
# Out:
#                 home_club_name score                     away_club_name  \
# game_id
# 2543981   Athletic Club Bilbao   1:3              Futbol Club Barcelona
# 2242853  Futbol Club Barcelona   2:2         Real Madrid Club de Fútbol
# 2594773  Futbol Club Barcelona   1:2         Real Madrid Club de Fútbol
# 2341135  Futbol Club Barcelona   2:1         Real Madrid Club de Fútbol
# 2475457  Futbol Club Barcelona   2:1         Real Madrid Club de Fútbol
# 2718844  Futbol Club Barcelona   1:1         Real Madrid Club de Fútbol
# 3177022  Futbol Club Barcelona   3:0            Liverpool Football Club
# 2899869  Futbol Club Barcelona   2:2         Real Madrid Club de Fútbol
# 2982007  Futbol Club Barcelona   3:0              Chelsea Football Club
# 2341258  Futbol Club Barcelona   1:1     Club Atlético de Madrid S.A.D.
# 3167768  Futbol Club Barcelona   3:0    Manchester United Football Club
# 2840942  Futbol Club Barcelona   0:0             Juventus Football Club
# 2754919  Futbol Club Barcelona   4:0      Manchester City Football Club
# 2805651  Futbol Club Barcelona   6:1  Paris Saint-Germain Football Club
# 2301903  Futbol Club Barcelona   1:1  Paris Saint-Germain Football Club
# 2312111  Futbol Club Barcelona   0:3                  FC Bayern München
# 3886591  Futbol Club Barcelona   2:1         Real Madrid Club de Fútbol
# 2560716  Futbol Club Barcelona   3:0                  FC Bayern München
# 2288676  Futbol Club Barcelona   1:3         Real Madrid Club de Fútbol
# 2284449  Futbol Club Barcelona   4:0          Associazione Calcio Milan
#
#          attendance           stadium        date
# game_id
# 2543981     99354.0  Spotify Camp Nou  30-05-2015
# 2242853     99354.0  Spotify Camp Nou  07-10-2012
# 2594773     98902.0  Spotify Camp Nou  02-04-2016
# 2341135     98761.0  Spotify Camp Nou  26-10-2013
# 2475457     98760.0  Spotify Camp Nou  22-03-2015
# 2718844     98485.0  Spotify Camp Nou  03-12-2016
# 3177022     98299.0  Spotify Camp Nou  01-05-2019
# 2899869     97939.0  Spotify Camp Nou  06-05-2018
# 2982007     97183.0  Spotify Camp Nou  14-03-2018
# 2341258     96973.0  Spotify Camp Nou  17-05-2014
# 3167768     96708.0  Spotify Camp Nou  16-04-2019
# 2840942     96290.0  Spotify Camp Nou  19-04-2017
# 2754919     96290.0  Spotify Camp Nou  19-10-2016
# 2805651     96290.0  Spotify Camp Nou  08-03-2017
# 2301903     96022.0  Spotify Camp Nou  10-04-2013
# 2312111     95877.0  Spotify Camp Nou  01-05-2013
# 3886591     95745.0  Spotify Camp Nou  19-03-2023
# 2560716     95639.0  Spotify Camp Nou  06-05-2015
# 2288676     95002.0  Spotify Camp Nou  26-02-2013
# 2284449     94944.0  Spotify Camp Nou  12-03-2013

# %%
# Stadi che hanno ospitato più partite
stadiums_count = games_df.groupby('stadium')['stadium'].value_counts().reset_index(name='matches_played')

df_sorted = stadiums_count.sort_values(by='matches_played', ascending=False).head(15)

sns.barplot(x='matches_played', y='stadium', data=df_sorted)
plt.title('Stadi che hanno ospitato il maggior numero di partite')
plt.ylabel('')
plt.xlabel('Numero di partite ospitate')
plt.show()

# %%
# media di gol segnati a partita per campionato

games_df['total_goals'] = games_df['home_club_goals'] + games_df['away_club_goals']

# Raggruppa per campionato e stagione e calcola la media dei gol segnati a partita
avg_goals_per_game = games_df.groupby('competition_id')['total_goals'].mean().reset_index(name='avg_goals').sort_values(by='avg_goals', ascending=False)

# code by ChatGPT
mapping_name = competitions_df.set_index('competition_id')['competition_name'].to_dict()
avg_goals_per_game['competition_name'] = avg_goals_per_game['competition_id'].map(mapping_name)
avg_goals_per_game = avg_goals_per_game.dropna(subset=['competition_name'])


ax = sns.barplot(data=avg_goals_per_game, x='avg_goals', y='competition_name')

for i, avg_goals in enumerate(avg_goals_per_game['avg_goals']):
    ax.text(avg_goals + 0.05, i, f'{avg_goals:.2f}', color='black', ha="left", va='center')

plt.title('Media di goal a partita per ogni Campionato')
plt.xlabel('Media di goal a partita')
plt.ylabel('')
plt.xlim(1,4)
plt.show()
