# %% [markdown]
# # Importing Data & Libraries

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from config import *

games_df = pd.read_csv(f"{folder_path}/games.csv")

# %% [markdown]
# # Data Preparation of Games

# %%
games_df.shape
# Out:
# (65216, 23)

# %%
games_df.head(10)
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 1  2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2  2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 3  2222664            RU1    2012   8. Matchday  2012-09-15           932
# 4  2222683            RU1    2012  12. Matchday  2012-10-22          2696
# 5  2222685            RU1    2012  19. Matchday  2012-12-10          2698
# 6  2222734            RU1    2012  19. Matchday  2012-12-07          1083
# 7  2222735            RU1    2012  18. Matchday  2012-12-02          2700
# 8  2222739            RU1    2012  22. Matchday  2013-03-31         16704
# 9  2222775            RU1    2012  28. Matchday  2013-05-12          3725
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0           232                2                1                 2.0  ...
# 1          4128                0                2                11.0  ...
# 2           121                0                2                 2.0  ...
# 3          2698                1                0                 5.0  ...
# 4         12438                0                1                11.0  ...
# 5           232                0                1                 7.0  ...
# 6         16704                2                3                11.0  ...
# 7          2410                2                0                 1.0  ...
# 8          2700                4                0                 8.0  ...
# 9          2700                1                0                 8.0  ...
#
#                   stadium attendance               referee  \
# 0            Akhmat-Arena    21700.0  Vladislav Bezborodov
# 1               Metallurg    11400.0         Sergey Ivanov
# 2            Arena Khimki    12000.0        Sergey Karasev
# 3               RZD Arena    11408.0        Sergey Karasev
# 4               Metallurg     7534.0     Timur Arslanbekov
# 5  Central Stadium  Kazan     8384.0  Vladislav Bezborodov
# 6                 Olimp-2     5700.0      Sergey Kuznetsov
# 7                  Dinamo    15500.0  Vladislav Bezborodov
# 8                   Kuban    18800.0      Aleksey Nikolaev
# 9            Akhmat-Arena    22000.0        Vitali Meshkov
#
#                                                  url  home_club_formation  \
# 0  https://www.transfermarkt.co.uk/terek-grozny_s...                  NaN
# 1  https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# 2  https://www.transfermarkt.co.uk/cska-moscow_di...                  NaN
# 3  https://www.transfermarkt.co.uk/lokomotiv-mosc...                  NaN
# 4  https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# 5  https://www.transfermarkt.co.uk/rubin-kazan_sp...                  NaN
# 6  https://www.transfermarkt.co.uk/fk-rostov_fk-k...                  NaN
# 7  https://www.transfermarkt.co.uk/anzhi-makhachk...                  NaN
# 8  https://www.transfermarkt.co.uk/fk-krasnodar_a...                  NaN
# 9  https://www.transfermarkt.co.uk/terek-grozny_a...                  NaN
#
#   away_club_formation                      home_club_name  \
# 0                 NaN                   RFK Akhmat Grozny
# 1                 NaN           PFK Krylya Sovetov Samara
# 2                 NaN                     PFK CSKA Moskva
# 3                 NaN  Футбольный клуб "Локомотив" Москва
# 4                 NaN           PFK Krylya Sovetov Samara
# 5                 NaN                      FC Rubin Kazan
# 6                 NaN                           FK Rostov
# 7                 NaN          Anzhi Makhachkala ( -2022)
# 8                 NaN                        FK Krasnodar
# 9                 NaN                   RFK Akhmat Grozny
#
#                     away_club_name aggregate competition_type
# 0                FK Spartak Moskva       2:1  domestic_league
# 1                       Amkar Perm       0:2  domestic_league
# 2                 FK Dinamo Moskva       0:2  domestic_league
# 3                   FC Rubin Kazan       1:0  domestic_league
# 4  Volga Nizhniy Novgorod (- 2016)       0:1  domestic_league
# 5                FK Spartak Moskva       0:1  domestic_league
# 6                     FK Krasnodar       2:3  domestic_league
# 7                  PFK CSKA Moskva       2:0  domestic_league
# 8       Anzhi Makhachkala ( -2022)       4:0  domestic_league
# 9       Anzhi Makhachkala ( -2022)       1:0  domestic_league
#
# [10 rows x 23 columns]

# %%
games_df = games_df.set_index('game_id')
games_df.head(10)
# Out:
#         competition_id  season         round        date  home_club_id  \
# game_id
# 2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 2222664            RU1    2012   8. Matchday  2012-09-15           932
# 2222683            RU1    2012  12. Matchday  2012-10-22          2696
# 2222685            RU1    2012  19. Matchday  2012-12-10          2698
# 2222734            RU1    2012  19. Matchday  2012-12-07          1083
# 2222735            RU1    2012  18. Matchday  2012-12-02          2700
# 2222739            RU1    2012  22. Matchday  2013-03-31         16704
# 2222775            RU1    2012  28. Matchday  2013-05-12          3725
#
#          away_club_id  home_club_goals  away_club_goals  home_club_position  \
# game_id
# 2222597           232                2                1                 2.0
# 2222627          4128                0                2                11.0
# 2222658           121                0                2                 2.0
# 2222664          2698                1                0                 5.0
# 2222683         12438                0                1                11.0
# 2222685           232                0                1                 7.0
# 2222734         16704                2                3                11.0
# 2222735          2410                2                0                 1.0
# 2222739          2700                4                0                 8.0
# 2222775          2700                1                0                 8.0
#
#          away_club_position  ...                 stadium attendance  \
# game_id                      ...
# 2222597                 5.0  ...            Akhmat-Arena    21700.0
# 2222627                10.0  ...               Metallurg    11400.0
# 2222658                13.0  ...            Arena Khimki    12000.0
# 2222664                 8.0  ...               RZD Arena    11408.0
# 2222683                16.0  ...               Metallurg     7534.0
# 2222685                 5.0  ...  Central Stadium  Kazan     8384.0
# 2222734                10.0  ...                 Olimp-2     5700.0
# 2222735                 2.0  ...                  Dinamo    15500.0
# 2222739                 3.0  ...                   Kuban    18800.0
# 2222775                 3.0  ...            Akhmat-Arena    22000.0
#
#                       referee  \
# game_id
# 2222597  Vladislav Bezborodov
# 2222627         Sergey Ivanov
# 2222658        Sergey Karasev
# 2222664        Sergey Karasev
# 2222683     Timur Arslanbekov
# 2222685  Vladislav Bezborodov
# 2222734      Sergey Kuznetsov
# 2222735  Vladislav Bezborodov
# 2222739      Aleksey Nikolaev
# 2222775        Vitali Meshkov
#
#                                                        url  \
# game_id
# 2222597  https://www.transfermarkt.co.uk/terek-grozny_s...
# 2222627  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222658  https://www.transfermarkt.co.uk/cska-moscow_di...
# 2222664  https://www.transfermarkt.co.uk/lokomotiv-mosc...
# 2222683  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222685  https://www.transfermarkt.co.uk/rubin-kazan_sp...
# 2222734  https://www.transfermarkt.co.uk/fk-rostov_fk-k...
# 2222735  https://www.transfermarkt.co.uk/anzhi-makhachk...
# 2222739  https://www.transfermarkt.co.uk/fk-krasnodar_a...
# 2222775  https://www.transfermarkt.co.uk/terek-grozny_a...
#
#         home_club_formation away_club_formation  \
# game_id
# 2222597                 NaN                 NaN
# 2222627                 NaN                 NaN
# 2222658                 NaN                 NaN
# 2222664                 NaN                 NaN
# 2222683                 NaN                 NaN
# 2222685                 NaN                 NaN
# 2222734                 NaN                 NaN
# 2222735                 NaN                 NaN
# 2222739                 NaN                 NaN
# 2222775                 NaN                 NaN
#
#                              home_club_name                   away_club_name  \
# game_id
# 2222597                   RFK Akhmat Grozny                FK Spartak Moskva
# 2222627           PFK Krylya Sovetov Samara                       Amkar Perm
# 2222658                     PFK CSKA Moskva                 FK Dinamo Moskva
# 2222664  Футбольный клуб "Локомотив" Москва                   FC Rubin Kazan
# 2222683           PFK Krylya Sovetov Samara  Volga Nizhniy Novgorod (- 2016)
# 2222685                      FC Rubin Kazan                FK Spartak Moskva
# 2222734                           FK Rostov                     FK Krasnodar
# 2222735          Anzhi Makhachkala ( -2022)                  PFK CSKA Moskva
# 2222739                        FK Krasnodar       Anzhi Makhachkala ( -2022)
# 2222775                   RFK Akhmat Grozny       Anzhi Makhachkala ( -2022)
#
#         aggregate competition_type
# game_id
# 2222597       2:1  domestic_league
# 2222627       0:2  domestic_league
# 2222658       0:2  domestic_league
# 2222664       1:0  domestic_league
# 2222683       0:1  domestic_league
# 2222685       0:1  domestic_league
# 2222734       2:3  domestic_league
# 2222735       2:0  domestic_league
# 2222739       4:0  domestic_league
# 2222775       1:0  domestic_league
#
# [10 rows x 22 columns]

# %%
games_df.columns
# Out:
# Index(['competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
games_df.loc[games_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [competition_id, season, round, date, home_club_id, away_club_id, home_club_goals, away_club_goals, home_club_position, away_club_position, home_club_manager_name, away_club_manager_name, stadium, attendance, referee, url, home_club_formation, away_club_formation, home_club_name, away_club_name, aggregate, competition_type]
# Index: []
#
# [0 rows x 22 columns]

# %%
# handling NA values
games_df.isna().sum()
# Out:
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  0
# away_club_id                  0
# home_club_goals               0
# away_club_goals               0
# home_club_position        19454
# away_club_position        19454
# home_club_manager_name      742
# away_club_manager_name      742
# stadium                     211
# attendance                 9512
# referee                     594
# url                           0
# home_club_formation       62347
# away_club_formation       62328
# home_club_name            11252
# away_club_name            10049
# aggregate                     0
# competition_type              0
# dtype: int64

# %%
# Toglie le righe in cui tutti i valori delle colonne elencate sono NaN
games_df = games_df.dropna(subset=['home_club_position','away_club_position','home_club_manager_name','away_club_manager_name','stadium','attendance','referee','home_club_formation','away_club_formation'], how='all')

games_df
# Out:
#         competition_id  season                     round        date  \
# game_id
# 2222597            RU1    2012               6. Matchday  2012-08-25
# 2222627            RU1    2012               5. Matchday  2012-08-20
# 2222658            RU1    2012              10. Matchday  2012-09-30
# 2222664            RU1    2012               8. Matchday  2012-09-15
# 2222683            RU1    2012              12. Matchday  2012-10-22
# ...                ...     ...                       ...         ...
# 2367292             EL    2013                   Group B  2013-11-07
# 2629035            NLP    2015               Third Round  2015-10-27
# 3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 4164101            CGB    2023              Second Round  2023-08-29
# 4013659            FAC    2022              Fourth Round  2023-01-29
#
#          home_club_id  away_club_id  home_club_goals  away_club_goals  \
# game_id
# 2222597          3725           232                2                1
# 2222627          2696          4128                0                2
# 2222658          2410           121                0                2
# 2222664           932          2698                1                0
# 2222683          2696         12438                0                1
# ...               ...           ...              ...              ...
# 2367292           383           419                2                0
# 2629035           383         16866                6                0
# 3092951           383           713                3                0
# 4164101           512          1194                6                1
# 4013659           512          3684                3                1
#
#          home_club_position  away_club_position  ...          stadium  \
# game_id                                          ...
# 2222597                 2.0                 5.0  ...     Akhmat-Arena
# 2222627                11.0                10.0  ...        Metallurg
# 2222658                 2.0                13.0  ...     Arena Khimki
# 2222664                 5.0                 8.0  ...        RZD Arena
# 2222683                11.0                16.0  ...        Metallurg
# ...                     ...                 ...  ...              ...
# 2367292                 NaN                 NaN  ...  Philips Stadion
# 2629035                 NaN                 NaN  ...  Philips Stadion
# 3092951                 NaN                 NaN  ...  Philips Stadion
# 4164101                 NaN                 NaN  ...   bet365 Stadium
# 4013659                 NaN                 NaN  ...   bet365 Stadium
#
#         attendance               referee  \
# game_id
# 2222597    21700.0  Vladislav Bezborodov
# 2222627    11400.0         Sergey Ivanov
# 2222658    12000.0        Sergey Karasev
# 2222664    11408.0        Sergey Karasev
# 2222683     7534.0     Timur Arslanbekov
# ...            ...                   ...
# 2367292    10000.0        Cristian Balaj
# 2629035    31000.0       Allard Lindhout
# 3092951    34200.0        Anthony Taylor
# 4164101     9410.0     Michael Salisbury
# 4013659    14392.0            David Webb
#
#                                                        url  \
# game_id
# 2222597  https://www.transfermarkt.co.uk/terek-grozny_s...
# 2222627  https://www.transfermarkt.co.uk/krylya-sovetov...
# 2222658  https://www.transfermarkt.co.uk/cska-moscow_di...
# 2222664  https://www.transfermarkt.co.uk/lokomotiv-mosc...
# 2222683  https://www.transfermarkt.co.uk/krylya-sovetov...
# ...                                                    ...
# 2367292  https://www.transfermarkt.co.uk/spielbericht/i...
# 2629035  https://www.transfermarkt.co.uk/spielbericht/i...
# 3092951  https://www.transfermarkt.co.uk/spielbericht/i...
# 4164101  https://www.transfermarkt.co.uk/spielbericht/i...
# 4013659  https://www.transfermarkt.co.uk/spielbericht/i...
#
#         home_club_formation away_club_formation  \
# game_id
# 2222597                 NaN                 NaN
# 2222627                 NaN                 NaN
# 2222658                 NaN                 NaN
# 2222664                 NaN                 NaN
# 2222683                 NaN                 NaN
# ...                     ...                 ...
# 2367292                 NaN                 NaN
# 2629035                 NaN                 NaN
# 3092951                 NaN                 NaN
# 4164101             4-2-3-1             4-2-3-1
# 4013659                 NaN                 NaN
#
#                                             home_club_name  \
# game_id
# 2222597                                  RFK Akhmat Grozny
# 2222627                          PFK Krylya Sovetov Samara
# 2222658                                    PFK CSKA Moskva
# 2222664                 Футбольный клуб "Локомотив" Москва
# 2222683                          PFK Krylya Sovetov Samara
# ...                                                    ...
# 2367292  Eindhovense Voetbalvereniging Philips Sport Ve...
# 2629035  Eindhovense Voetbalvereniging Philips Sport Ve...
# 3092951  Eindhovense Voetbalvereniging Philips Sport Ve...
# 4164101                                         Stoke City
# 4013659                                         Stoke City
#
#                           away_club_name aggregate   competition_type
# game_id
# 2222597                FK Spartak Moskva       2:1    domestic_league
# 2222627                       Amkar Perm       0:2    domestic_league
# 2222658                 FK Dinamo Moskva       0:2    domestic_league
# 2222664                   FC Rubin Kazan       1:0    domestic_league
# 2222683  Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                  ...       ...                ...
# 2367292                              NaN       2:0  international_cup
# 2629035                              NaN       6:0       domestic_cup
# 3092951                              NaN       3:0  international_cup
# 4164101                              NaN       6:1              other
# 4013659                              NaN       3:1       domestic_cup
#
# [65197 rows x 22 columns]

# %%
# Togliere le righe che non hanno nè squadra di casa nè squadra di trasferta
games_df = games_df.dropna(subset=['home_club_name','away_club_name'], how='all')

# %%
games_df.isna().sum()
# Out:
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  0
# away_club_id                  0
# home_club_goals               0
# away_club_goals               0
# home_club_position        11721
# away_club_position        11721
# home_club_manager_name      325
# away_club_manager_name      325
# stadium                      79
# attendance                 7583
# referee                     231
# url                           0
# home_club_formation       55274
# away_club_formation       55264
# home_club_name             3519
# away_club_name             2322
# aggregate                     0
# competition_type              0
# dtype: int64

# %%
# prendiamo i nomi delle squadre dal dataframe clubs, visto che abbiamo gli id delle squadre (in casa e in trasferta)

clubs_df = pd.read_csv(f"{folder_path}/clubs.csv")
clubs_df.columns
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'last_season',
#        'url'],
#       dtype='object')

# %%
games_df.columns
# Out:
# Index(['competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
# Aggiornamento di home_club_name
games_df = games_df.merge(clubs_df[['club_id', 'name']], how='left', left_on='home_club_id', right_on='club_id')
games_df['home_club_name'] = games_df['home_club_name'].fillna(games_df['name'])
games_df.drop(columns=['name', 'club_id'], inplace=True)

# Aggiornamento di away_club_name
games_df = games_df.merge(clubs_df[['club_id', 'name']], how='left', left_on='away_club_id', right_on='club_id')
games_df['away_club_name'] = games_df['away_club_name'].fillna(games_df['name'])
games_df.drop(columns=['name', 'club_id'], inplace=True)

games_df
# Out:
#       competition_id  season                     round        date  \
# 0                RU1    2012               6. Matchday  2012-08-25
# 1                RU1    2012               5. Matchday  2012-08-20
# 2                RU1    2012              10. Matchday  2012-09-30
# 3                RU1    2012               8. Matchday  2012-09-15
# 4                RU1    2012              12. Matchday  2012-10-22
# ...              ...     ...                       ...         ...
# 57478             EL    2013                   Group B  2013-11-07
# 57479            NLP    2015               Third Round  2015-10-27
# 57480            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 57481            CGB    2023              Second Round  2023-08-29
# 57482            FAC    2022              Fourth Round  2023-01-29
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 0              3725           232                2                1
# 1              2696          4128                0                2
# 2              2410           121                0                2
# 3               932          2698                1                0
# 4              2696         12438                0                1
# ...             ...           ...              ...              ...
# 57478           383           419                2                0
# 57479           383         16866                6                0
# 57480           383           713                3                0
# 57481           512          1194                6                1
# 57482           512          3684                3                1
#
#        home_club_position  away_club_position  ...          stadium  \
# 0                     2.0                 5.0  ...     Akhmat-Arena
# 1                    11.0                10.0  ...        Metallurg
# 2                     2.0                13.0  ...     Arena Khimki
# 3                     5.0                 8.0  ...        RZD Arena
# 4                    11.0                16.0  ...        Metallurg
# ...                   ...                 ...  ...              ...
# 57478                 NaN                 NaN  ...  Philips Stadion
# 57479                 NaN                 NaN  ...  Philips Stadion
# 57480                 NaN                 NaN  ...  Philips Stadion
# 57481                 NaN                 NaN  ...   bet365 Stadium
# 57482                 NaN                 NaN  ...   bet365 Stadium
#
#       attendance               referee  \
# 0        21700.0  Vladislav Bezborodov
# 1        11400.0         Sergey Ivanov
# 2        12000.0        Sergey Karasev
# 3        11408.0        Sergey Karasev
# 4         7534.0     Timur Arslanbekov
# ...          ...                   ...
# 57478    10000.0        Cristian Balaj
# 57479    31000.0       Allard Lindhout
# 57480    34200.0        Anthony Taylor
# 57481     9410.0     Michael Salisbury
# 57482    14392.0            David Webb
#
#                                                      url home_club_formation  \
# 0      https://www.transfermarkt.co.uk/terek-grozny_s...                 NaN
# 1      https://www.transfermarkt.co.uk/krylya-sovetov...                 NaN
# 2      https://www.transfermarkt.co.uk/cska-moscow_di...                 NaN
# 3      https://www.transfermarkt.co.uk/lokomotiv-mosc...                 NaN
# 4      https://www.transfermarkt.co.uk/krylya-sovetov...                 NaN
# ...                                                  ...                 ...
# 57478  https://www.transfermarkt.co.uk/spielbericht/i...                 NaN
# 57479  https://www.transfermarkt.co.uk/spielbericht/i...                 NaN
# 57480  https://www.transfermarkt.co.uk/spielbericht/i...                 NaN
# 57481  https://www.transfermarkt.co.uk/spielbericht/i...             4-2-3-1
# 57482  https://www.transfermarkt.co.uk/spielbericht/i...                 NaN
#
#       away_club_formation                                     home_club_name  \
# 0                     NaN                                  RFK Akhmat Grozny
# 1                     NaN                          PFK Krylya Sovetov Samara
# 2                     NaN                                    PFK CSKA Moskva
# 3                     NaN                 Футбольный клуб "Локомотив" Москва
# 4                     NaN                          PFK Krylya Sovetov Samara
# ...                   ...                                                ...
# 57478                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57479                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57480                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57481             4-2-3-1                                         Stoke City
# 57482                 NaN                                         Stoke City
#
#                         away_club_name aggregate   competition_type
# 0                    FK Spartak Moskva       2:1    domestic_league
# 1                           Amkar Perm       0:2    domestic_league
# 2                     FK Dinamo Moskva       0:2    domestic_league
# 3                       FC Rubin Kazan       1:0    domestic_league
# 4      Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                ...       ...                ...
# 57478                              NaN       2:0  international_cup
# 57479                              NaN       6:0       domestic_cup
# 57480                              NaN       3:0  international_cup
# 57481                              NaN       6:1              other
# 57482                              NaN       3:1       domestic_cup
#
# [57483 rows x 22 columns]

# %%
games_df.isna().sum()
# Out:
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  0
# away_club_id                  0
# home_club_goals               0
# away_club_goals               0
# home_club_position        11721
# away_club_position        11721
# home_club_manager_name      325
# away_club_manager_name      325
# stadium                      79
# attendance                 7583
# referee                     231
# url                           0
# home_club_formation       55274
# away_club_formation       55264
# home_club_name             3519
# away_club_name             2322
# aggregate                     0
# competition_type              0
# dtype: int64

# %%
# le righe con il nome della squadra ancora NA sono quelle che non sono presenti nel csv clubs, quindi le rimuoviamo
games_df.dropna(subset=['home_club_name', 'away_club_name'])
# Out:
#       competition_id  season         round        date  home_club_id  \
# 0                RU1    2012   6. Matchday  2012-08-25          3725
# 1                RU1    2012   5. Matchday  2012-08-20          2696
# 2                RU1    2012  10. Matchday  2012-09-30          2410
# 3                RU1    2012   8. Matchday  2012-09-15           932
# 4                RU1    2012  12. Matchday  2012-10-22          2696
# ...              ...     ...           ...         ...           ...
# 57432            NL1    2022  12. Matchday  2022-10-30           383
# 57433            NL1    2015  23. Matchday  2016-02-14           467
# 57434            NL1    2016  23. Matchday  2017-02-18           383
# 57435            NL1    2022  27. Matchday  2023-04-01           467
# 57436            NL1    2023   5. Matchday  2023-09-16           383
#
#        away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 0               232                2                1                 2.0
# 1              4128                0                2                11.0
# 2               121                0                2                 2.0
# 3              2698                1                0                 5.0
# 4             12438                0                1                11.0
# ...             ...              ...              ...                 ...
# 57432           467                3                0                 2.0
# 57433           383                0                3                 8.0
# 57434           467                3                1                 3.0
# 57435           383                2                4                10.0
# 57436           467                4                0                 1.0
#
#        away_club_position  ...          stadium attendance  \
# 0                     5.0  ...     Akhmat-Arena    21700.0
# 1                    10.0  ...        Metallurg    11400.0
# 2                    13.0  ...     Arena Khimki    12000.0
# 3                     8.0  ...        RZD Arena    11408.0
# 4                    16.0  ...        Metallurg     7534.0
# ...                   ...  ...              ...        ...
# 57432                15.0  ...  Philips Stadion    31007.0
# 57433                 1.0  ...   Goffertstadion    12353.0
# 57434                12.0  ...  Philips Stadion    33500.0
# 57435                 3.0  ...   Goffertstadion    12500.0
# 57436                13.0  ...  Philips Stadion    34200.0
#
#                       referee  \
# 0        Vladislav Bezborodov
# 1               Sergey Ivanov
# 2              Sergey Karasev
# 3              Sergey Karasev
# 4           Timur Arslanbekov
# ...                       ...
# 57432  Martin van den Kerkhof
# 57433              Kevin Blom
# 57434         Jochem Kamphuis
# 57435      Edwin van de Graaf
# 57436              Joey Kooij
#
#                                                      url home_club_formation  \
# 0      https://www.transfermarkt.co.uk/terek-grozny_s...                 NaN
# 1      https://www.transfermarkt.co.uk/krylya-sovetov...                 NaN
# 2      https://www.transfermarkt.co.uk/cska-moscow_di...                 NaN
# 3      https://www.transfermarkt.co.uk/lokomotiv-mosc...                 NaN
# 4      https://www.transfermarkt.co.uk/krylya-sovetov...                 NaN
# ...                                                  ...                 ...
# 57432  https://www.transfermarkt.co.uk/psv-eindhoven_...                 NaN
# 57433  https://www.transfermarkt.co.uk/nec-nijmegen_p...                 NaN
# 57434  https://www.transfermarkt.co.uk/psv-eindhoven_...                 NaN
# 57435  https://www.transfermarkt.co.uk/nec-nijmegen_p...                 NaN
# 57436  https://www.transfermarkt.co.uk/psv-eindhoven_...     4-3-3 Attacking
#
#       away_club_formation                                     home_club_name  \
# 0                     NaN                                  RFK Akhmat Grozny
# 1                     NaN                          PFK Krylya Sovetov Samara
# 2                     NaN                                    PFK CSKA Moskva
# 3                     NaN                 Футбольный клуб "Локомотив" Москва
# 4                     NaN                          PFK Krylya Sovetov Samara
# ...                   ...                                                ...
# 57432                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57433                 NaN                      Nijmegen Eendracht Combinatie
# 57434                 NaN  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57435                 NaN                      Nijmegen Eendracht Combinatie
# 57436     4-3-3 Defending  Eindhovense Voetbalvereniging Philips Sport Ve...
#
#                                           away_club_name aggregate  \
# 0                                      FK Spartak Moskva       2:1
# 1                                             Amkar Perm       0:2
# 2                                       FK Dinamo Moskva       0:2
# 3                                         FC Rubin Kazan       1:0
# 4                        Volga Nizhniy Novgorod (- 2016)       0:1
# ...                                                  ...       ...
# 57432                      Nijmegen Eendracht Combinatie       3:0
# 57433  Eindhovense Voetbalvereniging Philips Sport Ve...       0:3
# 57434                      Nijmegen Eendracht Combinatie       3:1
# 57435  Eindhovense Voetbalvereniging Philips Sport Ve...       2:4
# 57436                      Nijmegen Eendracht Combinatie       4:0
#
#       competition_type
# 0      domestic_league
# 1      domestic_league
# 2      domestic_league
# 3      domestic_league
# 4      domestic_league
# ...                ...
# 57432  domestic_league
# 57433  domestic_league
# 57434  domestic_league
# 57435  domestic_league
# 57436  domestic_league
#
# [51642 rows x 22 columns]

# %%
# gestione valori NA di position e attendance
games_df['home_club_position'].fillna(0, inplace=True)
games_df['away_club_position'].fillna(0, inplace=True)
games_df['attendance'].fillna(0, inplace=True)

# gestione valori NA delle formazioni
games_df['home_club_formation'].fillna('Unknown', inplace=True)
games_df['away_club_formation'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Louis\AppData\Local\Temp\ipykernel_18916\3254614655.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   games_df['home_club_position'].fillna(0, inplace=True)
# C:\Users\Louis\AppData\Local\Temp\ipykernel_18916\3254614655.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   games_df['away_club_position'].fillna(0, inplace=True)
# C:\Users\Louis\AppData\Local\Temp\ipykernel_18916\3254614655.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   games_df['attendance'].fillna(0, inplace=True)
# C:\Users\Louis\AppData\Local\Temp\ipykernel_18916\3254614655.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   games_df['home_club_formation'].fillna('Unknown', inplace=True)
# C:\Users\Louis\AppData\Local\Temp\ipykernel_18916\3254614655.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   games_df['away_club_formation'].fillna('Unknown', inplace=True)

# %%
games_df.dtypes
# Out:
# competition_id             object
# season                      int64
# round                      object
# date                       object
# home_club_id                int64
# away_club_id                int64
# home_club_goals             int64
# away_club_goals             int64
# home_club_position        float64
# away_club_position        float64
# home_club_manager_name     object
# away_club_manager_name     object
# stadium                    object
# attendance                float64
# referee                    object
# url                        object
# home_club_formation        object
# away_club_formation        object
# home_club_name             object
# away_club_name             object
# aggregate                  object
# competition_type           object
# dtype: object

# %%
# conversione date
games_df['date'] = pd.to_datetime(games_df['date']).dt.strftime('%d-%m-%Y')

# conversione position a int
games_df['home_club_position'] = games_df['home_club_position'].astype('int64')
games_df['away_club_position'] = games_df['away_club_position'].astype('int64')

# conversione attendance a int
games_df['attendance'] = games_df['attendance'].astype('int64')


games_df
# Out:
#       competition_id  season                     round        date  \
# 0                RU1    2012               6. Matchday  25-08-2012
# 1                RU1    2012               5. Matchday  20-08-2012
# 2                RU1    2012              10. Matchday  30-09-2012
# 3                RU1    2012               8. Matchday  15-09-2012
# 4                RU1    2012              12. Matchday  22-10-2012
# ...              ...     ...                       ...         ...
# 57478             EL    2013                   Group B  07-11-2013
# 57479            NLP    2015               Third Round  27-10-2015
# 57480            CLQ    2018  Qualifying Round 2nd leg  29-08-2018
# 57481            CGB    2023              Second Round  29-08-2023
# 57482            FAC    2022              Fourth Round  29-01-2023
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 0              3725           232                2                1
# 1              2696          4128                0                2
# 2              2410           121                0                2
# 3               932          2698                1                0
# 4              2696         12438                0                1
# ...             ...           ...              ...              ...
# 57478           383           419                2                0
# 57479           383         16866                6                0
# 57480           383           713                3                0
# 57481           512          1194                6                1
# 57482           512          3684                3                1
#
#        home_club_position  away_club_position  ...          stadium  \
# 0                       2                   5  ...     Akhmat-Arena
# 1                      11                  10  ...        Metallurg
# 2                       2                  13  ...     Arena Khimki
# 3                       5                   8  ...        RZD Arena
# 4                      11                  16  ...        Metallurg
# ...                   ...                 ...  ...              ...
# 57478                   0                   0  ...  Philips Stadion
# 57479                   0                   0  ...  Philips Stadion
# 57480                   0                   0  ...  Philips Stadion
# 57481                   0                   0  ...   bet365 Stadium
# 57482                   0                   0  ...   bet365 Stadium
#
#       attendance               referee  \
# 0          21700  Vladislav Bezborodov
# 1          11400         Sergey Ivanov
# 2          12000        Sergey Karasev
# 3          11408        Sergey Karasev
# 4           7534     Timur Arslanbekov
# ...          ...                   ...
# 57478      10000        Cristian Balaj
# 57479      31000       Allard Lindhout
# 57480      34200        Anthony Taylor
# 57481       9410     Michael Salisbury
# 57482      14392            David Webb
#
#                                                      url home_club_formation  \
# 0      https://www.transfermarkt.co.uk/terek-grozny_s...             Unknown
# 1      https://www.transfermarkt.co.uk/krylya-sovetov...             Unknown
# 2      https://www.transfermarkt.co.uk/cska-moscow_di...             Unknown
# 3      https://www.transfermarkt.co.uk/lokomotiv-mosc...             Unknown
# 4      https://www.transfermarkt.co.uk/krylya-sovetov...             Unknown
# ...                                                  ...                 ...
# 57478  https://www.transfermarkt.co.uk/spielbericht/i...             Unknown
# 57479  https://www.transfermarkt.co.uk/spielbericht/i...             Unknown
# 57480  https://www.transfermarkt.co.uk/spielbericht/i...             Unknown
# 57481  https://www.transfermarkt.co.uk/spielbericht/i...             4-2-3-1
# 57482  https://www.transfermarkt.co.uk/spielbericht/i...             Unknown
#
#       away_club_formation                                     home_club_name  \
# 0                 Unknown                                  RFK Akhmat Grozny
# 1                 Unknown                          PFK Krylya Sovetov Samara
# 2                 Unknown                                    PFK CSKA Moskva
# 3                 Unknown                 Футбольный клуб "Локомотив" Москва
# 4                 Unknown                          PFK Krylya Sovetov Samara
# ...                   ...                                                ...
# 57478             Unknown  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57479             Unknown  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57480             Unknown  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57481             4-2-3-1                                         Stoke City
# 57482             Unknown                                         Stoke City
#
#                         away_club_name aggregate   competition_type
# 0                    FK Spartak Moskva       2:1    domestic_league
# 1                           Amkar Perm       0:2    domestic_league
# 2                     FK Dinamo Moskva       0:2    domestic_league
# 3                       FC Rubin Kazan       1:0    domestic_league
# 4      Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                ...       ...                ...
# 57478                              NaN       2:0  international_cup
# 57479                              NaN       6:0       domestic_cup
# 57480                              NaN       3:0  international_cup
# 57481                              NaN       6:1              other
# 57482                              NaN       3:1       domestic_cup
#
# [57483 rows x 22 columns]

# %%
#making a dataframe subset and reordering columns
games_df = games_df [
    ['competition_id', 
     'season', 
     'round', 
     'date', 
     'home_club_id',
     'home_club_name',
     'home_club_goals',
     'home_club_position', 
     'home_club_manager_name',
     'home_club_formation', 
     'away_club_id',  
     'away_club_name',
     'away_club_goals',
     'away_club_position', 
     'away_club_manager_name', 
     'away_club_formation', 
     'stadium', 
     'attendance', 
     'referee', 
     #'url',
     'aggregate', 
     'competition_type']
]

games_df
# Out:
#       competition_id  season                     round        date  \
# 0                RU1    2012               6. Matchday  25-08-2012
# 1                RU1    2012               5. Matchday  20-08-2012
# 2                RU1    2012              10. Matchday  30-09-2012
# 3                RU1    2012               8. Matchday  15-09-2012
# 4                RU1    2012              12. Matchday  22-10-2012
# ...              ...     ...                       ...         ...
# 57478             EL    2013                   Group B  07-11-2013
# 57479            NLP    2015               Third Round  27-10-2015
# 57480            CLQ    2018  Qualifying Round 2nd leg  29-08-2018
# 57481            CGB    2023              Second Round  29-08-2023
# 57482            FAC    2022              Fourth Round  29-01-2023
#
#        home_club_id                                     home_club_name  \
# 0              3725                                  RFK Akhmat Grozny
# 1              2696                          PFK Krylya Sovetov Samara
# 2              2410                                    PFK CSKA Moskva
# 3               932                 Футбольный клуб "Локомотив" Москва
# 4              2696                          PFK Krylya Sovetov Samara
# ...             ...                                                ...
# 57478           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57479           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57480           383  Eindhovense Voetbalvereniging Philips Sport Ve...
# 57481           512                                         Stoke City
# 57482           512                                         Stoke City
#
#        home_club_goals  home_club_position home_club_manager_name  \
# 0                    2                   2   Stanislav Cherchesov
# 1                    0                  11         Andrey Kobelev
# 2                    0                   2         Leonid Slutski
# 3                    1                   5           Slaven Bilic
# 4                    0                  11         Andrey Kobelev
# ...                ...                 ...                    ...
# 57478                2                   0           Phillip Cocu
# 57479                6                   0           Phillip Cocu
# 57480                3                   0        Mark van Bommel
# 57481                6                   0              Alex Neil
# 57482                3                   0              Alex Neil
#
#       home_club_formation  ...                   away_club_name  \
# 0                 Unknown  ...                FK Spartak Moskva
# 1                 Unknown  ...                       Amkar Perm
# 2                 Unknown  ...                 FK Dinamo Moskva
# 3                 Unknown  ...                   FC Rubin Kazan
# 4                 Unknown  ...  Volga Nizhniy Novgorod (- 2016)
# ...                   ...  ...                              ...
# 57478             Unknown  ...                              NaN
# 57479             Unknown  ...                              NaN
# 57480             Unknown  ...                              NaN
# 57481             4-2-3-1  ...                              NaN
# 57482             Unknown  ...                              NaN
#
#       away_club_goals  away_club_position  away_club_manager_name  \
# 0                   1                   5              Unai Emery
# 1                   2                  10           Rustem Khuzin
# 2                   2                  13            Dan Petrescu
# 3                   0                   8          Kurban Berdyev
# 4                   1                  16         Gadzhi Gadzhiev
# ...               ...                 ...                     ...
# 57478               0                   0             Zoran Mamic
# 57479               0                   0        Hennie in 't Hof
# 57480               0                   0            Aleksey Baga
# 57481               1                   0             Matt Taylor
# 57482               1                   0             Steve Evans
#
#       away_club_formation          stadium attendance               referee  \
# 0                 Unknown     Akhmat-Arena      21700  Vladislav Bezborodov
# 1                 Unknown        Metallurg      11400         Sergey Ivanov
# 2                 Unknown     Arena Khimki      12000        Sergey Karasev
# 3                 Unknown        RZD Arena      11408        Sergey Karasev
# 4                 Unknown        Metallurg       7534     Timur Arslanbekov
# ...                   ...              ...        ...                   ...
# 57478             Unknown  Philips Stadion      10000        Cristian Balaj
# 57479             Unknown  Philips Stadion      31000       Allard Lindhout
# 57480             Unknown  Philips Stadion      34200        Anthony Taylor
# 57481             4-2-3-1   bet365 Stadium       9410     Michael Salisbury
# 57482             Unknown   bet365 Stadium      14392            David Webb
#
#       aggregate   competition_type
# 0           2:1    domestic_league
# 1           0:2    domestic_league
# 2           0:2    domestic_league
# 3           1:0    domestic_league
# 4           0:1    domestic_league
# ...         ...                ...
# 57478       2:0  international_cup
# 57479       6:0       domestic_cup
# 57480       3:0  international_cup
# 57481       6:1              other
# 57482       3:1       domestic_cup
#
# [57483 rows x 21 columns]

# %%
games_df = games_df.rename(columns={'aggregate':'score'})

# %%
# check for home goal outliers
ax = games_df.boxplot(column='home_club_goals')
ax.set_title('Numbers of goals in Home Club')
plt.show()

# %%
# check for away goal outliers
ax = games_df.boxplot(column='away_club_goals')
ax.set_title('Numbers of goals in Away Club')
plt.show()

# %%
# attendance distribution
df = games_df.query('attendance > 0')
var = 'attendance'

mean_value = df[var].mean()
print(f"Media di {var}: {mean_value:.0f} spettatori")

sns.histplot(data=df, x=var, kde=True, bins=20)
plt.title(f'Distribuzione della variabile {var}')
plt.xlabel(f'{var}')
plt.ylabel('count')
plt.show()
# Out:
# Media di attendance: 19625 spettatori

# %% [markdown]
# # Saving processed data to feather file

# %%
games_df.to_feather('../cleaned_data/games.feather')
